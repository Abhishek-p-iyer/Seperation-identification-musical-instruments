# %%
import warnings
warnings.filterwarnings('ignore')

#import data lib
import numpy as np
import pickle
import itertools

# %%
#import sys lib
import os, fnmatch

# %%
#import visual lib
import seaborn
import matplotlib.pyplot as plt
from IPython.core.display import HTML, display

# %%
#import ML lib
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import recall_score, precision_score, accuracy_score
from sklearn.metrics import confusion_matrix, f1_score, classification_report
from sklearn.svm import LinearSVC, SVC
from sklearn.externals import joblib

# %%
#random seed
from numpy.random import seed
seed(1)

# %%
#import audio lib
import librosa.display, librosa

# %%
#configurations
path = './audio'

# %%
#Get files 

files = []
for root, dirnames, filenames in os.walk(path):
    for filename in fnmatch.filter(filenames, '*.mp3'):
        files.append(os.path.join(root, filename))
        
print("found {} audio files in {}".format(len(files), path))
# Out:
# found 4555 audio files in ./audio

# %%
#Get lables to identify number of different samples by listing
'''
labels=[]
classes=['cello', 'flute', 'oboe', 'viola', 'sax', 'trumpet']
colour_dict={'cello':'blue', 'flute':'red', 'oboe':'green', 'trumpet':'black', 'sax':'magenta', 'viola':'yellow'}
colour_list=[]
for filename in files:
    for name in classes:
        temp = list(filename.split("\\"))
        print(temp)
        if name in temp:
            labels.append(name)
            colour_list.append(colour_dict[name])
            break
        else:
            labels.append('other')

labels=[]
classes=['cello', 'flute', 'oboe', 'viola', 'sax', 'trumpet']
colour_dict={'cello':'blue', 'flute':'red', 'oboe':'green', 'trumpet':'black', 'sax':'magenta', 'viola':'yellow'}
colour_list=[]
for filename in files:
    for name in classes:
        if fnmatch.fnmatchcase(filename, '*'+name+'*'):
            labels.append(name)
            colour_list.append(colour_dict[name])
            break
        else:
            labels.append('other')
'''

labels=[]
classes=['cello', 'flute', 'oboe', 'viola', 'sax', 'trumpet']
colour_dict={'cello':'blue', 'flute':'red', 'oboe':'green', 'trumpet':'black', 'sax':'magenta', 'viola':'yellow'}
colour_list=[]
for filename in files:
    if fnmatch.fnmatchcase(filename, '*'+'cello'+'*'):
            labels.append('cello')
            colour_list.append(colour_dict['cello'])
            #break
    elif fnmatch.fnmatchcase(filename, '*'+'flute'+'*'):
            labels.append('flute')
            colour_list.append(colour_dict['flute'])
            #break
    elif fnmatch.fnmatchcase(filename, '*'+'oboe'+'*'):
            labels.append('oboe')
            colour_list.append(colour_dict['oboe'])
            #break
    elif fnmatch.fnmatchcase(filename, '*'+'viola'+'*'):
            labels.append('viola')
            colour_list.append(colour_dict['viola'])
            #break
    elif fnmatch.fnmatchcase(filename, '*'+'sax'+'*'):
            labels.append('sax')
            colour_list.append(colour_dict['sax'])
            #break
    elif fnmatch.fnmatchcase(filename, '*'+'trumpet'+'*'):
            labels.append('trumpet')
            colour_list.append(colour_dict['trumpet'])
            #break
    else:
            labels.append('other')

# %%
print(labels)
print(colour_list)
print(len(colour_list))
import pandas as pd
pd.options.display.max_rows = 50000
# Out:
# ['cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'cello', 'ce ...
# ['blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', ...
# 4555

# %%
# Encode labels
labelencoder=LabelEncoder()
labelencoder.fit(labels)
print(len(labelencoder.classes_), "classes:", ", ".join(list(labelencoder.classes_)))
classes_num=labelencoder.transform(labels)
classes_num.shape[0]
# Out:
# 6 classes: cello, flute, oboe, sax, trumpet, viola
# 4555

# %%
# Parameter for MFCC
fs=44100 #sampling frequency
n_fft=2048 #length of FFT window
hop_length=512 #Number of samples between successive frames
n_mels=128 #number of mel bands
n_mfcc=13 #number of MFCCs

# %%
#Defining funtion for calculating audio features
def get_features(y, sr=fs):
    S = librosa.feature.melspectrogram(y, sr=fs, n_mels=n_mfcc)
    mfcc=librosa.feature.mfcc(S=librosa.power_to_db(S), n_mfcc=n_mfcc)
    feature_vector=np.mean(mfcc, 1)
    return feature_vector

# %%
# LOADING THEM AND CREATING FEATURES VECTORS (FOR CONFUSION MATRIX)

feature_vectors = []
sound_paths = []
for i,f in enumerate(files):
    print("get %d of %d = %s"%(i+1, len(files), f))
    try:
        y, sr = librosa.load(f, sr = fs)
        y/=y.max() #Normalize 
        if len(y) < 2:
            print("error loading %s" %f)
            continue 
        feat = get_features(y, sr)
        feature_vectors.append(feat)
        sound_paths.append(f)
    except Exception as e:
        print("erroe loading %s. Error: %s" % (f,e))


print("Calculated %d feature vectors" %len(feature_vectors))
# Out:
# get 1 of 4555 = ./audio\cello\cello_A2_025_forte_arco-normal.mp3
# get 2 of 4555 = ./audio\cello\cello_A2_025_fortissimo_arco-normal.mp3
# get 3 of 4555 = ./audio\cello\cello_A2_025_mezzo-forte_arco-col-legno-battuto.mp3
# get 4 of 4555 = ./audio\cello\cello_A2_025_mezzo-piano_arco-normal.mp3
# get 5 of 4555 = ./audio\cello\cello_A2_025_pianissimo_arco-normal.mp3
# get 6 of 4555 = ./audio\cello\cello_A2_05_forte_arco-normal.mp3
# get 7 of 4555 = ./audio\cello\cello_A2_05_fortissimo_arco-normal.mp3
# get 8 of 4555 = ./audio\cello\cello_A2_05_mezzo-piano_arco-normal.mp3
# get 9 of 4555 = ./audio\cello\cello_A2_05_pianissimo_arco-normal.mp3
# get 10 of 4555 = ./audio\cello\cello_A2_15_forte_arco-normal.mp3
# get 11 of 4555 = ./audio\cello\cello_A2_15_pianissimo_arco-normal.mp3
# get 12 of 4555 = ./audio\cello\cello_A2_15_piano_arco-normal.mp3
# get 13 of 4555 = ./audio\cello\cello_A2_1_forte_arco-normal.mp3
# get 14 of 4555 = ./audio\cello\cello_A2_1_fortissimo_arco-normal.mp3
# get 15 of 4555 = ./audio\cello\cello_A2_1_mezzo-piano_arco-normal.mp3
# get 16 of 4555 = ./audio\cello\cello_A2_1_mezzo-piano_non-vibrato.mp3
# get 17 of 4555 = ./audio\cello\cello_A2_1_pianissimo_arco-normal.mp3
# get 18 of 4555 = ./audio\cello\cello_A3_025_forte_arco-normal.mp3
# get 19 of 4555 = ./audio\cello\cello_A3_025_fortissimo_arco-normal.mp3
# get 20 of 4555 = ./audio\cello\cello_A3_025_mezzo-forte_arco-col-legno-battuto.mp3
# get 21 of 4555 = ./audio\cello\cello_A3_025_mezzo-piano_arco-normal.mp3
# get 22 of 4555 = ./audio\cello\cello_A3_025_pianissimo_arco-normal.mp3
# get 23 of 4555 = ./audio\cello\cello_A3_05_forte_arco-normal.mp3
# get 24 of 4555 = ./audio\cello\cello_A3_05_fortissimo_arco-normal.mp3
# get 25 of 4555 = ./audio\cello\cello_A3_05_mezzo-piano_arco-normal.mp3
# get 26 of 4555 = ./audio\cello\cello_A3_15_forte_arco-normal.mp3
# get 27 of 4555 = ./audio\cello\cello_A3_15_mezzo-piano_arco-normal.mp3
# get 28 of 4555 = ./audio\cello\cello_A3_1_forte_arco-normal.mp3
# get 29 of 4555 = ./audio\cello\cello_A3_1_fortissimo_arco-normal.mp3
# get 30 of 4555 = ./audio\cello\cello_A3_1_mezzo-piano_arco-minor-trill.mp3
# get 31 of 4555 = ./audio\cello\cello_A3_1_mezzo-piano_arco-normal.mp3
# get 32 of 4555 = ./audio\cello\cello_A3_1_mezzo-piano_non-vibrato.mp3
# get 33 of 4555 = ./audio\cello\cello_A3_1_pianissimo_arco-normal.mp3
# get 34 of 4555 = ./audio\cello\cello_A3_phrase_cresc-decresc_arco-normal.mp3
# get 35 of 4555 = ./audio\cello\cello_A3_phrase_fortissimo_arco-tremolo.mp3
# get 36 of 4555 = ./audio\cello\cello_A3_phrase_mezzo-forte_arco-detache.mp3
# get 37 of 4555 = ./audio\cello\cello_A3_phrase_mezzo-forte_arco-legato.mp3
# get 38 of 4555 = ./audio\cello\cello_A3_phrase_mezzo-forte_arco-spiccato.mp3
# get 39 of 4555 = ./audio\cello\cello_A3_phrase_mezzo-forte_arco-staccato.mp3
# get 40 of 4555 = ./audio\cello\cello_A4_025_forte_arco-normal.mp3
# get 41 of 4555 = ./audio\cello\cello_A4_025_fortissimo_arco-normal.mp3
# get 42 of 4555 = ./audio\cello\cello_A4_025_mezzo-forte_arco-col-legno-battuto.mp3
# get 43 of 4555 = ./audio\cello\cello_A4_025_mezzo-piano_arco-normal.mp3
# get 44 of 4555 = ./audio\cello\cello_A4_025_pianissimo_arco-normal.mp3
# get 45 of 4555 = ./audio\cello\cello_A4_05_forte_arco-normal.mp3
# get 46 of 4555 = ./audio\cello\cello_A4_05_mezzo-piano_arco-normal.mp3
# get 47 of 4555 = ./audio\cello\cello_A4_05_pianissimo_arco-normal.mp3
# get 48 of 4555 = ./audio\cello\cello_A4_15_forte_arco-normal.mp3
# get 49 of 4555 = ./audio\cello\cello_A4_15_mezzo-piano_arco-normal.mp3
# get 50 of 4555 = ./audio\cello\cello_A4_1_forte_arco-normal.mp3
# get 51 of 4555 = ./audio\cello\cello_A4_1_fortissimo_arco-normal.mp3
# get 52 of 4555 = ./audio\cello\cello_A4_1_mezzo-forte_arco-harmonic.mp3
# get 53 of 4555 = ./audio\cello\cello_A4_1_mezzo-piano_arco-minor-trill.mp3
# get 54 of 4555 = ./audio\cello\cello_A4_1_mezzo-piano_arco-normal.mp3
# get 55 of 4555 = ./audio\cello\cello_A4_1_mezzo-piano_molto-vibrato.mp3
# get 56 of 4555 = ./audio\cello\cello_A4_1_pianissimo_arco-normal.mp3
# get 57 of 4555 = ./audio\cello\cello_A4_phrase_mezzo-forte_arco-detache.mp3
# get 58 of 4555 = ./audio\cello\cello_A4_phrase_mezzo-forte_arco-legato.mp3
# get 59 of 4555 = ./audio\cello\cello_A4_phrase_mezzo-forte_arco-spiccato.mp3
# get 60 of 4555 = ./audio\cello\cello_A4_phrase_mezzo-forte_arco-staccato.mp3
# get 61 of 4555 = ./audio\cello\cello_A5_025_forte_arco-normal.mp3
# get 62 of 4555 = ./audio\cello\cello_A5_025_fortissimo_arco-normal.mp3
# get 63 of 4555 = ./audio\cello\cello_A5_025_mezzo-piano_arco-normal.mp3
# get 64 of 4555 = ./audio\cello\cello_A5_025_pianissimo_arco-normal.mp3
# get 65 of 4555 = ./audio\cello\cello_A5_05_forte_arco-normal.mp3
# get 66 of 4555 = ./audio\cello\cello_A5_05_fortissimo_arco-normal.mp3
# get 67 of 4555 = ./audio\cello\cello_A5_05_mezzo-piano_arco-normal.mp3
# get 68 of 4555 = ./audio\cello\cello_A5_05_pianissimo_arco-normal.mp3
# get 69 of 4555 = ./audio\cello\cello_A5_15_forte_arco-normal.mp3
# get 70 of 4555 = ./audio\cello\cello_A5_15_mezzo-piano_arco-normal.mp3
# get 71 of 4555 = ./audio\cello\cello_A5_15_pianissimo_arco-normal.mp3
# get 72 of 4555 = ./audio\cello\cello_A5_1_forte_arco-normal.mp3
# get 73 of 4555 = ./audio\cello\cello_A5_1_fortissimo_arco-normal.mp3
# get 74 of 4555 = ./audio\cello\cello_A5_1_mezzo-forte_arco-harmonic.mp3
# get 75 of 4555 = ./audio\cello\cello_A5_1_mezzo-piano_arco-normal.mp3
# get 76 of 4555 = ./audio\cello\cello_A5_1_pianissimo_arco-normal.mp3
# get 77 of 4555 = ./audio\cello\cello_As2_025_forte_arco-normal.mp3
# get 78 of 4555 = ./audio\cello\cello_As2_025_fortissimo_arco-normal.mp3
# get 79 of 4555 = ./audio\cello\cello_As2_025_mezzo-forte_arco-col-legno-battuto.mp3
# get 80 of 4555 = ./audio\cello\cello_As2_025_mezzo-piano_arco-normal.mp3
# get 81 of 4555 = ./audio\cello\cello_As2_025_pianissimo_arco-normal.mp3
# get 82 of 4555 = ./audio\cello\cello_As2_05_forte_arco-normal.mp3
# get 83 of 4555 = ./audio\cello\cello_As2_05_fortissimo_arco-normal.mp3
# get 84 of 4555 = ./audio\cello\cello_As2_05_mezzo-piano_arco-normal.mp3
# get 85 of 4555 = ./audio\cello\cello_As2_05_pianissimo_arco-normal.mp3
# get 86 of 4555 = ./audio\cello\cello_As2_15_forte_arco-normal.mp3
# get 87 of 4555 = ./audio\cello\cello_As2_15_fortissimo_arco-normal.mp3
# get 88 of 4555 = ./audio\cello\cello_As2_15_pianissimo_arco-normal.mp3
# get 89 of 4555 = ./audio\cello\cello_As2_15_piano_arco-normal.mp3
# get 90 of 4555 = ./audio\cello\cello_As2_1_forte_arco-normal.mp3
# get 91 of 4555 = ./audio\cello\cello_As2_1_fortissimo_arco-normal.mp3
# get 92 of 4555 = ./audio\cello\cello_As2_1_mezzo-piano_arco-minor-trill.mp3
# get 93 of 4555 = ./audio\cello\cello_As2_1_mezzo-piano_arco-normal.mp3
# get 94 of 4555 = ./audio\cello\cello_As2_1_mezzo-piano_molto-vibrato.mp3
# get 95 of 4555 = ./audio\cello\cello_As2_1_mezzo-piano_non-vibrato.mp3
# get 96 of 4555 = ./audio\cello\cello_As2_1_pianissimo_arco-normal.mp3
# get 97 of 4555 = ./audio\cello\cello_As3_025_forte_arco-normal.mp3
# get 98 of 4555 = ./audio\cello\cello_As3_025_fortissimo_arco-normal.mp3
# get 99 of 4555 = ./audio\cello\cello_As3_025_mezzo-piano_arco-normal.mp3
# get 100 of 4555 = ./audio\cello\cello_As3_025_pianissimo_arco-normal.mp3
# get 101 of 4555 = ./audio\cello\cello_As3_05_forte_arco-normal.mp3
# get 102 of 4555 = ./audio\cello\cello_As3_05_fortissimo_arco-normal.mp3
# get 103 of 4555 = ./audio\cello\cello_As3_05_mezzo-piano_arco-normal.mp3
# get 104 of 4555 = ./audio\cello\cello_As3_05_pianissimo_arco-normal.mp3
# get 105 of 4555 = ./audio\cello\cello_As3_15_forte_arco-normal.mp3
# get 106 of 4555 = ./audio\cello\cello_As3_15_fortissimo_arco-normal.mp3
# get 107 of 4555 = ./audio\cello\cello_As3_15_mezzo-piano_arco-normal.mp3
# get 108 of 4555 = ./audio\cello\cello_As3_15_pianissimo_arco-normal.mp3
# get 109 of 4555 = ./audio\cello\cello_As3_1_forte_arco-normal.mp3
# get 110 of 4555 = ./audio\cello\cello_As3_1_fortissimo_arco-normal.mp3
# get 111 of 4555 = ./audio\cello\cello_As3_1_mezzo-piano_arco-normal.mp3
# get 112 of 4555 = ./audio\cello\cello_As3_1_pianissimo_arco-normal.mp3
# get 113 of 4555 = ./audio\cello\cello_As4_025_forte_arco-normal.mp3
# get 114 of 4555 = ./audio\cello\cello_As4_025_fortissimo_arco-normal.mp3
# get 115 of 4555 = ./audio\cello\cello_As4_025_mezzo-piano_arco-normal.mp3
# get 116 of 4555 = ./audio\cello\cello_As4_025_pianissimo_arco-normal.mp3
# get 117 of 4555 = ./audio\cello\cello_As4_05_forte_arco-normal.mp3
# get 118 of 4555 = ./audio\cello\cello_As4_05_fortissimo_arco-normal.mp3
# get 119 of 4555 = ./audio\cello\cello_As4_05_mezzo-piano_arco-normal.mp3
# get 120 of 4555 = ./audio\cello\cello_As4_05_pianissimo_arco-normal.mp3
# get 121 of 4555 = ./audio\cello\cello_As4_15_forte_arco-normal.mp3
# get 122 of 4555 = ./audio\cello\cello_As4_15_fortissimo_arco-normal.mp3
# get 123 of 4555 = ./audio\cello\cello_As4_15_mezzo-piano_arco-normal.mp3
# get 124 of 4555 = ./audio\cello\cello_As4_15_pianissimo_arco-normal.mp3
# get 125 of 4555 = ./audio\cello\cello_As4_1_forte_arco-normal.mp3
# get 126 of 4555 = ./audio\cello\cello_As4_1_fortissimo_arco-normal.mp3
# get 127 of 4555 = ./audio\cello\cello_As4_1_mezzo-piano_arco-normal.mp3
# get 128 of 4555 = ./audio\cello\cello_As4_1_pianissimo_arco-normal.mp3
# get 129 of 4555 = ./audio\cello\cello_As4_long_mezzo-forte_arco-harmonic.mp3
# get 130 of 4555 = ./audio\cello\cello_As5_025_forte_arco-normal.mp3
# get 131 of 4555 = ./audio\cello\cello_As5_025_fortissimo_arco-normal.mp3
# get 132 of 4555 = ./audio\cello\cello_As5_025_mezzo-piano_arco-normal.mp3
# get 133 of 4555 = ./audio\cello\cello_As5_025_pianissimo_arco-normal.mp3
# get 134 of 4555 = ./audio\cello\cello_As5_05_forte_arco-normal.mp3
# get 135 of 4555 = ./audio\cello\cello_As5_05_fortissimo_arco-normal.mp3
# get 136 of 4555 = ./audio\cello\cello_As5_05_mezzo-piano_arco-normal.mp3
# get 137 of 4555 = ./audio\cello\cello_As5_05_pianissimo_arco-normal.mp3
# get 138 of 4555 = ./audio\cello\cello_As5_15_forte_arco-normal.mp3
# get 139 of 4555 = ./audio\cello\cello_As5_15_fortissimo_arco-normal.mp3
# get 140 of 4555 = ./audio\cello\cello_As5_15_mezzo-piano_arco-normal.mp3
# get 141 of 4555 = ./audio\cello\cello_As5_15_pianissimo_arco-normal.mp3
# get 142 of 4555 = ./audio\cello\cello_As5_1_forte_arco-normal.mp3
# get 143 of 4555 = ./audio\cello\cello_As5_1_fortissimo_arco-normal.mp3
# get 144 of 4555 = ./audio\cello\cello_As5_1_mezzo-piano_arco-normal.mp3
# get 145 of 4555 = ./audio\cello\cello_As5_1_pianissimo_arco-normal.mp3
# get 146 of 4555 = ./audio\cello\cello_As6_1_mezzo-forte_arco-harmonic.mp3
# get 147 of 4555 = ./audio\cello\cello_B2_025_forte_arco-normal.mp3
# get 148 of 4555 = ./audio\cello\cello_B2_025_fortissimo_arco-normal.mp3
# get 149 of 4555 = ./audio\cello\cello_B2_025_mezzo-forte_arco-col-legno-battuto.mp3
# get 150 of 4555 = ./audio\cello\cello_B2_025_mezzo-piano_arco-normal.mp3
# get 151 of 4555 = ./audio\cello\cello_B2_025_pianissimo_arco-normal.mp3
# get 152 of 4555 = ./audio\cello\cello_B2_025_piano_arco-normal.mp3
# get 153 of 4555 = ./audio\cello\cello_B2_05_forte_arco-normal.mp3
# get 154 of 4555 = ./audio\cello\cello_B2_05_fortissimo_arco-normal.mp3
# get 155 of 4555 = ./audio\cello\cello_B2_05_mezzo-piano_arco-normal.mp3
# get 156 of 4555 = ./audio\cello\cello_B2_05_pianissimo_arco-normal.mp3
# get 157 of 4555 = ./audio\cello\cello_B2_15_forte_arco-normal.mp3
# get 158 of 4555 = ./audio\cello\cello_B2_15_fortissimo_arco-normal.mp3
# get 159 of 4555 = ./audio\cello\cello_B2_15_pianissimo_arco-normal.mp3
# get 160 of 4555 = ./audio\cello\cello_B2_15_piano_arco-normal.mp3
# get 161 of 4555 = ./audio\cello\cello_B2_1_forte_arco-normal.mp3
# get 162 of 4555 = ./audio\cello\cello_B2_1_fortissimo_arco-normal.mp3
# get 163 of 4555 = ./audio\cello\cello_B2_1_mezzo-piano_arco-major-trill.mp3
# get 164 of 4555 = ./audio\cello\cello_B2_1_pianissimo_arco-normal.mp3
# get 165 of 4555 = ./audio\cello\cello_B3_025_forte_arco-normal.mp3
# get 166 of 4555 = ./audio\cello\cello_B3_025_fortissimo_arco-normal.mp3
# get 167 of 4555 = ./audio\cello\cello_B3_025_pianissimo_arco-normal.mp3
# get 168 of 4555 = ./audio\cello\cello_B3_05_forte_arco-normal.mp3
# get 169 of 4555 = ./audio\cello\cello_B3_05_fortissimo_arco-normal.mp3
# get 170 of 4555 = ./audio\cello\cello_B3_05_mezzo-piano_arco-normal.mp3
# get 171 of 4555 = ./audio\cello\cello_B3_05_pianissimo_arco-normal.mp3
# get 172 of 4555 = ./audio\cello\cello_B3_15_forte_arco-normal.mp3
# get 173 of 4555 = ./audio\cello\cello_B3_15_fortissimo_arco-normal.mp3
# get 174 of 4555 = ./audio\cello\cello_B3_15_mezzo-piano_arco-normal.mp3
# get 175 of 4555 = ./audio\cello\cello_B3_15_pianissimo_arco-normal.mp3
# get 176 of 4555 = ./audio\cello\cello_B3_1_fortissimo_arco-normal.mp3
# get 177 of 4555 = ./audio\cello\cello_B3_1_mezzo-piano_arco-normal.mp3
# get 178 of 4555 = ./audio\cello\cello_B3_1_pianissimo_arco-normal.mp3
# get 179 of 4555 = ./audio\cello\cello_B4_025_forte_arco-normal.mp3
# get 180 of 4555 = ./audio\cello\cello_B4_025_fortissimo_arco-normal.mp3
# get 181 of 4555 = ./audio\cello\cello_B4_025_mezzo-piano_arco-normal.mp3
# get 182 of 4555 = ./audio\cello\cello_B4_025_pianissimo_arco-normal.mp3
# get 183 of 4555 = ./audio\cello\cello_B4_05_forte_arco-normal.mp3
# get 184 of 4555 = ./audio\cello\cello_B4_05_fortissimo_arco-normal.mp3
# get 185 of 4555 = ./audio\cello\cello_B4_05_mezzo-piano_arco-normal.mp3
# get 186 of 4555 = ./audio\cello\cello_B4_05_pianissimo_arco-normal.mp3
# get 187 of 4555 = ./audio\cello\cello_B4_15_forte_arco-normal.mp3
# get 188 of 4555 = ./audio\cello\cello_B4_15_fortissimo_arco-normal.mp3
# get 189 of 4555 = ./audio\cello\cello_B4_15_mezzo-piano_arco-normal.mp3
# get 190 of 4555 = ./audio\cello\cello_B4_15_pianissimo_arco-normal.mp3
# get 191 of 4555 = ./audio\cello\cello_B4_1_forte_arco-normal.mp3
# get 192 of 4555 = ./audio\cello\cello_B4_1_fortissimo_arco-normal.mp3
# get 193 of 4555 = ./audio\cello\cello_B4_1_mezzo-piano_arco-minor-trill.mp3
# get 194 of 4555 = ./audio\cello\cello_B4_1_mezzo-piano_arco-normal.mp3
# get 195 of 4555 = ./audio\cello\cello_B4_1_pianissimo_arco-normal.mp3
# get 196 of 4555 = ./audio\cello\cello_B5_025_forte_arco-normal.mp3
# get 197 of 4555 = ./audio\cello\cello_B5_025_fortissimo_arco-normal.mp3
# get 198 of 4555 = ./audio\cello\cello_B5_025_mezzo-piano_arco-normal.mp3
# get 199 of 4555 = ./audio\cello\cello_B5_025_pianissimo_arco-normal.mp3
# get 200 of 4555 = ./audio\cello\cello_B5_05_forte_arco-normal.mp3
# get 201 of 4555 = ./audio\cello\cello_B5_05_fortissimo_arco-normal.mp3
# get 202 of 4555 = ./audio\cello\cello_B5_05_mezzo-piano_arco-normal.mp3
# get 203 of 4555 = ./audio\cello\cello_B5_05_pianissimo_arco-normal.mp3
# get 204 of 4555 = ./audio\cello\cello_B5_15_forte_arco-normal.mp3
# get 205 of 4555 = ./audio\cello\cello_B5_15_fortissimo_arco-normal.mp3
# get 206 of 4555 = ./audio\cello\cello_B5_15_mezzo-piano_arco-normal.mp3
# get 207 of 4555 = ./audio\cello\cello_B5_15_pianissimo_arco-normal.mp3
# get 208 of 4555 = ./audio\cello\cello_B5_1_forte_arco-normal.mp3
# get 209 of 4555 = ./audio\cello\cello_B5_1_fortissimo_arco-normal.mp3
# get 210 of 4555 = ./audio\cello\cello_B5_1_mezzo-piano_arco-normal.mp3
# get 211 of 4555 = ./audio\cello\cello_B5_1_pianissimo_arco-normal.mp3
# get 212 of 4555 = ./audio\cello\cello_C2_025_forte_arco-normal.mp3
# get 213 of 4555 = ./audio\cello\cello_C2_025_fortissimo_arco-normal.mp3
# get 214 of 4555 = ./audio\cello\cello_C2_025_mezzo-forte_arco-col-legno-battuto.mp3
# get 215 of 4555 = ./audio\cello\cello_C2_025_mezzo-piano_arco-normal.mp3
# get 216 of 4555 = ./audio\cello\cello_C2_05_forte_arco-normal.mp3
# get 217 of 4555 = ./audio\cello\cello_C2_05_mezzo-piano_arco-normal.mp3
# get 218 of 4555 = ./audio\cello\cello_C2_05_pianissimo_arco-normal.mp3
# get 219 of 4555 = ./audio\cello\cello_C2_15_forte_arco-normal.mp3
# get 220 of 4555 = ./audio\cello\cello_C2_15_fortissimo_arco-normal.mp3
# get 221 of 4555 = ./audio\cello\cello_C2_15_pianissimo_arco-normal.mp3
# get 222 of 4555 = ./audio\cello\cello_C2_15_piano_arco-normal.mp3
# get 223 of 4555 = ./audio\cello\cello_C2_1_forte_arco-normal.mp3
# get 224 of 4555 = ./audio\cello\cello_C2_1_fortissimo_arco-normal.mp3
# get 225 of 4555 = ./audio\cello\cello_C2_1_mezzo-piano_arco-minor-trill.mp3
# get 226 of 4555 = ./audio\cello\cello_C2_1_mezzo-piano_arco-normal.mp3
# get 227 of 4555 = ./audio\cello\cello_C2_1_mezzo-piano_molto-vibrato.mp3
# get 228 of 4555 = ./audio\cello\cello_C2_1_mezzo-piano_non-vibrato.mp3
# get 229 of 4555 = ./audio\cello\cello_C2_1_pianissimo_arco-normal.mp3
# get 230 of 4555 = ./audio\cello\cello_C2_1_piano_arco-major-trill.mp3
# get 231 of 4555 = ./audio\cello\cello_C2_phrase_forte_con-sord.mp3
# get 232 of 4555 = ./audio\cello\cello_C2_phrase_forte_molto-vibrato.mp3
# get 233 of 4555 = ./audio\cello\cello_C2_phrase_forte_non-vibrato.mp3
# get 234 of 4555 = ./audio\cello\cello_C2_phrase_forte_snap-pizz.mp3
# get 235 of 4555 = ./audio\cello\cello_C2_phrase_fortissimo_arco-au-talon.mp3
# get 236 of 4555 = ./audio\cello\cello_C2_phrase_fortissimo_arco-sul-ponticello.mp3
# get 237 of 4555 = ./audio\cello\cello_C2_phrase_fortissimo_pizz-normal.mp3
# get 238 of 4555 = ./audio\cello\cello_C2_phrase_mezzo-forte_arco-col-legno-tratto.mp3
# get 239 of 4555 = ./audio\cello\cello_C2_phrase_mezzo-forte_arco-detache.mp3
# get 240 of 4555 = ./audio\cello\cello_C2_phrase_mezzo-forte_arco-glissando.mp3
# get 241 of 4555 = ./audio\cello\cello_C2_phrase_mezzo-forte_arco-legato.mp3
# get 242 of 4555 = ./audio\cello\cello_C2_phrase_mezzo-forte_arco-spiccato.mp3
# get 243 of 4555 = ./audio\cello\cello_C2_phrase_mezzo-forte_arco-staccato.mp3
# get 244 of 4555 = ./audio\cello\cello_C2_phrase_mezzo-piano_arco-tremolo.mp3
# get 245 of 4555 = ./audio\cello\cello_C2_phrase_piano_arco-sul-tasto.mp3
# get 246 of 4555 = ./audio\cello\cello_C2_phrase_piano_con-sord.mp3
# get 247 of 4555 = ./audio\cello\cello_C2_phrase_piano_pizz-normal.mp3
# get 248 of 4555 = ./audio\cello\cello_C3_025_forte_arco-normal.mp3
# get 249 of 4555 = ./audio\cello\cello_C3_025_fortissimo_arco-normal.mp3
# get 250 of 4555 = ./audio\cello\cello_C3_025_mezzo-forte_arco-col-legno-battuto.mp3
# get 251 of 4555 = ./audio\cello\cello_C3_025_mezzo-piano_arco-normal.mp3
# get 252 of 4555 = ./audio\cello\cello_C3_025_piano_arco-normal.mp3
# get 253 of 4555 = ./audio\cello\cello_C3_05_forte_arco-normal.mp3
# get 254 of 4555 = ./audio\cello\cello_C3_05_fortissimo_arco-normal.mp3
# get 255 of 4555 = ./audio\cello\cello_C3_05_pianissimo_arco-normal.mp3
# get 256 of 4555 = ./audio\cello\cello_C3_15_forte_arco-normal.mp3
# get 257 of 4555 = ./audio\cello\cello_C3_15_fortissimo_arco-normal.mp3
# get 258 of 4555 = ./audio\cello\cello_C3_15_pianissimo_arco-normal.mp3
# get 259 of 4555 = ./audio\cello\cello_C3_15_piano_arco-normal.mp3
# get 260 of 4555 = ./audio\cello\cello_C3_1_forte_arco-normal.mp3
# get 261 of 4555 = ./audio\cello\cello_C3_1_fortissimo_arco-normal.mp3
# get 262 of 4555 = ./audio\cello\cello_C3_1_mezzo-piano_arco-major-trill.mp3
# get 263 of 4555 = ./audio\cello\cello_C3_1_mezzo-piano_arco-normal.mp3
# get 264 of 4555 = ./audio\cello\cello_C3_1_mezzo-piano_non-vibrato.mp3
# get 265 of 4555 = ./audio\cello\cello_C3_1_pianissimo_arco-normal.mp3
# get 266 of 4555 = ./audio\cello\cello_C3_phrase_cresc-decresc_arco-normal.mp3
# get 267 of 4555 = ./audio\cello\cello_C3_phrase_fortissimo_arco-tremolo.mp3
# get 268 of 4555 = ./audio\cello\cello_C3_phrase_mezzo-forte_arco-detache.mp3
# get 269 of 4555 = ./audio\cello\cello_C3_phrase_mezzo-forte_arco-legato.mp3
# get 270 of 4555 = ./audio\cello\cello_C3_phrase_mezzo-forte_arco-spiccato.mp3
# get 271 of 4555 = ./audio\cello\cello_C3_phrase_mezzo-forte_arco-staccato.mp3
# get 272 of 4555 = ./audio\cello\cello_C4_025_forte_arco-normal.mp3
# get 273 of 4555 = ./audio\cello\cello_C4_025_fortissimo_arco-normal.mp3
# get 274 of 4555 = ./audio\cello\cello_C4_025_mezzo-piano_arco-normal.mp3
# get 275 of 4555 = ./audio\cello\cello_C4_025_pianissimo_arco-normal.mp3
# get 276 of 4555 = ./audio\cello\cello_C4_05_fortissimo_arco-normal.mp3
# get 277 of 4555 = ./audio\cello\cello_C4_05_mezzo-piano_arco-normal.mp3
# get 278 of 4555 = ./audio\cello\cello_C4_05_pianissimo_arco-normal.mp3
# get 279 of 4555 = ./audio\cello\cello_C4_15_forte_arco-normal.mp3
# get 280 of 4555 = ./audio\cello\cello_C4_15_fortissimo_arco-normal.mp3
# get 281 of 4555 = ./audio\cello\cello_C4_15_mezzo-piano_arco-normal.mp3
# get 282 of 4555 = ./audio\cello\cello_C4_15_pianissimo_arco-normal.mp3
# get 283 of 4555 = ./audio\cello\cello_C4_1_forte_arco-normal.mp3
# get 284 of 4555 = ./audio\cello\cello_C4_1_fortissimo_arco-normal.mp3
# get 285 of 4555 = ./audio\cello\cello_C4_1_mezzo-piano_arco-minor-trill.mp3
# get 286 of 4555 = ./audio\cello\cello_C4_1_mezzo-piano_arco-normal.mp3
# get 287 of 4555 = ./audio\cello\cello_C4_1_pianissimo_arco-normal.mp3
# get 288 of 4555 = ./audio\cello\cello_C4_long_mezzo-forte_arco-harmonic.mp3
# get 289 of 4555 = ./audio\cello\cello_C4_phrase_cresc-decresc_arco-normal.mp3
# get 290 of 4555 = ./audio\cello\cello_C5_025_forte_arco-normal.mp3
# get 291 of 4555 = ./audio\cello\cello_C5_025_fortissimo_arco-normal.mp3
# get 292 of 4555 = ./audio\cello\cello_C5_025_mezzo-piano_arco-normal.mp3
# get 293 of 4555 = ./audio\cello\cello_C5_025_pianissimo_arco-normal.mp3
# get 294 of 4555 = ./audio\cello\cello_C5_05_forte_arco-normal.mp3
# get 295 of 4555 = ./audio\cello\cello_C5_05_fortissimo_arco-normal.mp3
# get 296 of 4555 = ./audio\cello\cello_C5_05_mezzo-piano_arco-normal.mp3
# get 297 of 4555 = ./audio\cello\cello_C5_05_pianissimo_arco-normal.mp3
# get 298 of 4555 = ./audio\cello\cello_C5_15_forte_arco-normal.mp3
# get 299 of 4555 = ./audio\cello\cello_C5_15_mezzo-piano_arco-normal.mp3
# get 300 of 4555 = ./audio\cello\cello_C5_15_pianissimo_arco-normal.mp3
# get 301 of 4555 = ./audio\cello\cello_C5_1_forte_arco-normal.mp3
# get 302 of 4555 = ./audio\cello\cello_C5_1_fortissimo_arco-normal.mp3
# get 303 of 4555 = ./audio\cello\cello_C5_1_mezzo-forte_arco-harmonic.mp3
# get 304 of 4555 = ./audio\cello\cello_C5_1_mezzo-piano_arco-normal.mp3
# get 305 of 4555 = ./audio\cello\cello_C5_1_mezzo-piano_non-vibrato.mp3
# get 306 of 4555 = ./audio\cello\cello_C5_1_pianissimo_arco-normal.mp3
# get 307 of 4555 = ./audio\cello\cello_C5_phrase_piano_arco-sul-tasto.mp3
# get 308 of 4555 = ./audio\cello\cello_C6_025_forte_arco-normal.mp3
# get 309 of 4555 = ./audio\cello\cello_C6_025_fortissimo_arco-normal.mp3
# get 310 of 4555 = ./audio\cello\cello_C6_025_mezzo-piano_arco-normal.mp3
# get 311 of 4555 = ./audio\cello\cello_C6_025_pianissimo_arco-normal.mp3
# get 312 of 4555 = ./audio\cello\cello_C6_05_forte_arco-normal.mp3
# get 313 of 4555 = ./audio\cello\cello_C6_05_fortissimo_arco-normal.mp3
# get 314 of 4555 = ./audio\cello\cello_C6_05_mezzo-piano_arco-normal.mp3
# get 315 of 4555 = ./audio\cello\cello_C6_05_pianissimo_arco-normal.mp3
# get 316 of 4555 = ./audio\cello\cello_C6_15_forte_arco-normal.mp3
# get 317 of 4555 = ./audio\cello\cello_C6_15_fortissimo_arco-normal.mp3
# get 318 of 4555 = ./audio\cello\cello_C6_15_mezzo-piano_arco-normal.mp3
# get 319 of 4555 = ./audio\cello\cello_C6_15_pianissimo_arco-normal.mp3
# get 320 of 4555 = ./audio\cello\cello_C6_1_forte_arco-normal.mp3
# get 321 of 4555 = ./audio\cello\cello_C6_1_fortissimo_arco-normal.mp3
# get 322 of 4555 = ./audio\cello\cello_C6_1_mezzo-piano_arco-normal.mp3
# get 323 of 4555 = ./audio\cello\cello_C6_1_pianissimo_arco-normal.mp3
# get 324 of 4555 = ./audio\cello\cello_C7_1_mezzo-forte_arco-harmonic.mp3
# get 325 of 4555 = ./audio\cello\cello_Cs2_025_forte_arco-normal.mp3
# get 326 of 4555 = ./audio\cello\cello_Cs2_025_fortissimo_arco-normal.mp3
# get 327 of 4555 = ./audio\cello\cello_Cs2_025_mezzo-forte_arco-col-legno-battuto.mp3
# get 328 of 4555 = ./audio\cello\cello_Cs2_025_mezzo-piano_arco-normal.mp3
# get 329 of 4555 = ./audio\cello\cello_Cs2_025_pianissimo_arco-normal.mp3
# get 330 of 4555 = ./audio\cello\cello_Cs2_025_piano_arco-normal.mp3
# get 331 of 4555 = ./audio\cello\cello_Cs2_05_forte_arco-normal.mp3
# get 332 of 4555 = ./audio\cello\cello_Cs2_05_fortissimo_arco-normal.mp3
# get 333 of 4555 = ./audio\cello\cello_Cs2_05_pianissimo_arco-normal.mp3
# get 334 of 4555 = ./audio\cello\cello_Cs2_15_forte_arco-normal.mp3
# get 335 of 4555 = ./audio\cello\cello_Cs2_15_fortissimo_arco-normal.mp3
# get 336 of 4555 = ./audio\cello\cello_Cs2_15_pianissimo_arco-normal.mp3
# get 337 of 4555 = ./audio\cello\cello_Cs2_15_piano_arco-normal.mp3
# get 338 of 4555 = ./audio\cello\cello_Cs2_1_forte_arco-normal.mp3
# get 339 of 4555 = ./audio\cello\cello_Cs2_1_fortissimo_arco-normal.mp3
# get 340 of 4555 = ./audio\cello\cello_Cs2_1_mezzo-piano_arco-normal.mp3
# get 341 of 4555 = ./audio\cello\cello_Cs2_1_mezzo-piano_non-vibrato.mp3
# get 342 of 4555 = ./audio\cello\cello_Cs2_1_pianissimo_arco-normal.mp3
# get 343 of 4555 = ./audio\cello\cello_Cs2_1_piano_arco-major-trill.mp3
# get 344 of 4555 = ./audio\cello\cello_Cs3_025_forte_arco-normal.mp3
# get 345 of 4555 = ./audio\cello\cello_Cs3_025_fortissimo_arco-normal.mp3
# get 346 of 4555 = ./audio\cello\cello_Cs3_025_pianissimo_arco-normal.mp3
# get 347 of 4555 = ./audio\cello\cello_Cs3_025_piano_arco-normal.mp3
# get 348 of 4555 = ./audio\cello\cello_Cs3_05_forte_arco-normal.mp3
# get 349 of 4555 = ./audio\cello\cello_Cs3_05_fortissimo_arco-normal.mp3
# get 350 of 4555 = ./audio\cello\cello_Cs3_05_pianissimo_arco-normal.mp3
# get 351 of 4555 = ./audio\cello\cello_Cs3_05_piano_arco-normal.mp3
# get 352 of 4555 = ./audio\cello\cello_Cs3_15_forte_arco-normal.mp3
# get 353 of 4555 = ./audio\cello\cello_Cs3_15_fortissimo_arco-normal.mp3
# get 354 of 4555 = ./audio\cello\cello_Cs3_15_pianissimo_arco-normal.mp3
# get 355 of 4555 = ./audio\cello\cello_Cs3_15_piano_arco-normal.mp3
# get 356 of 4555 = ./audio\cello\cello_Cs3_1_forte_arco-normal.mp3
# get 357 of 4555 = ./audio\cello\cello_Cs3_1_fortissimo_arco-normal.mp3
# get 358 of 4555 = ./audio\cello\cello_Cs3_1_mezzo-piano_non-vibrato.mp3
# get 359 of 4555 = ./audio\cello\cello_Cs3_1_pianissimo_arco-normal.mp3
# get 360 of 4555 = ./audio\cello\cello_Cs3_1_piano_arco-normal.mp3
# get 361 of 4555 = ./audio\cello\cello_Cs4_025_forte_arco-normal.mp3
# get 362 of 4555 = ./audio\cello\cello_Cs4_025_fortissimo_arco-normal.mp3
# get 363 of 4555 = ./audio\cello\cello_Cs4_025_mezzo-piano_arco-normal.mp3
# get 364 of 4555 = ./audio\cello\cello_Cs4_025_pianissimo_arco-normal.mp3
# get 365 of 4555 = ./audio\cello\cello_Cs4_05_forte_arco-normal.mp3
# get 366 of 4555 = ./audio\cello\cello_Cs4_05_pianissimo_arco-normal.mp3
# get 367 of 4555 = ./audio\cello\cello_Cs4_15_forte_arco-normal.mp3
# get 368 of 4555 = ./audio\cello\cello_Cs4_15_fortissimo_arco-normal.mp3
# get 369 of 4555 = ./audio\cello\cello_Cs4_15_mezzo-piano_arco-normal.mp3
# get 370 of 4555 = ./audio\cello\cello_Cs4_15_pianissimo_arco-normal.mp3
# get 371 of 4555 = ./audio\cello\cello_Cs4_1_forte_arco-normal.mp3
# get 372 of 4555 = ./audio\cello\cello_Cs4_1_fortissimo_arco-normal.mp3
# get 373 of 4555 = ./audio\cello\cello_Cs4_1_mezzo-piano_arco-normal.mp3
# get 374 of 4555 = ./audio\cello\cello_Cs4_1_mezzo-piano_non-vibrato.mp3
# get 375 of 4555 = ./audio\cello\cello_Cs4_1_pianissimo_arco-normal.mp3
# get 376 of 4555 = ./audio\cello\cello_Cs5_025_forte_arco-normal.mp3
# get 377 of 4555 = ./audio\cello\cello_Cs5_025_fortissimo_arco-normal.mp3
# get 378 of 4555 = ./audio\cello\cello_Cs5_025_mezzo-piano_arco-normal.mp3
# get 379 of 4555 = ./audio\cello\cello_Cs5_025_pianissimo_arco-normal.mp3
# get 380 of 4555 = ./audio\cello\cello_Cs5_05_forte_arco-normal.mp3
# get 381 of 4555 = ./audio\cello\cello_Cs5_05_fortissimo_arco-normal.mp3
# get 382 of 4555 = ./audio\cello\cello_Cs5_05_mezzo-piano_arco-normal.mp3
# get 383 of 4555 = ./audio\cello\cello_Cs5_05_pianissimo_arco-normal.mp3
# get 384 of 4555 = ./audio\cello\cello_Cs5_15_forte_arco-normal.mp3
# get 385 of 4555 = ./audio\cello\cello_Cs5_15_fortissimo_arco-normal.mp3
# get 386 of 4555 = ./audio\cello\cello_Cs5_15_mezzo-piano_arco-normal.mp3
# get 387 of 4555 = ./audio\cello\cello_Cs5_1_forte_arco-normal.mp3
# get 388 of 4555 = ./audio\cello\cello_Cs5_1_fortissimo_arco-normal.mp3
# get 389 of 4555 = ./audio\cello\cello_Cs5_1_mezzo-piano_arco-normal.mp3
# get 390 of 4555 = ./audio\cello\cello_Cs5_1_pianissimo_arco-normal.mp3
# get 391 of 4555 = ./audio\cello\cello_Cs6_1_mezzo-forte_arco-harmonic.mp3
# get 392 of 4555 = ./audio\cello\cello_D2_025_forte_arco-normal.mp3
# get 393 of 4555 = ./audio\cello\cello_D2_025_fortissimo_arco-normal.mp3
# get 394 of 4555 = ./audio\cello\cello_D2_025_mezzo-piano_arco-normal.mp3
# get 395 of 4555 = ./audio\cello\cello_D2_025_pianissimo_arco-normal.mp3
# get 396 of 4555 = ./audio\cello\cello_D2_05_forte_arco-normal.mp3
# get 397 of 4555 = ./audio\cello\cello_D2_05_fortissimo_arco-normal.mp3
# get 398 of 4555 = ./audio\cello\cello_D2_05_mezzo-piano_arco-normal.mp3
# get 399 of 4555 = ./audio\cello\cello_D2_05_pianissimo_arco-normal.mp3
# get 400 of 4555 = ./audio\cello\cello_D2_15_forte_arco-normal.mp3
# get 401 of 4555 = ./audio\cello\cello_D2_15_fortissimo_arco-normal.mp3
# get 402 of 4555 = ./audio\cello\cello_D2_15_mezzo-piano_arco-normal.mp3
# get 403 of 4555 = ./audio\cello\cello_D2_15_pianissimo_arco-normal.mp3
# get 404 of 4555 = ./audio\cello\cello_D2_1_forte_arco-normal.mp3
# get 405 of 4555 = ./audio\cello\cello_D2_1_fortissimo_arco-normal.mp3
# get 406 of 4555 = ./audio\cello\cello_D2_1_mezzo-piano_arco-normal.mp3
# get 407 of 4555 = ./audio\cello\cello_D2_1_pianissimo_arco-normal.mp3
# get 408 of 4555 = ./audio\cello\cello_D3_025_forte_arco-normal.mp3
# get 409 of 4555 = ./audio\cello\cello_D3_025_fortissimo_arco-normal.mp3
# get 410 of 4555 = ./audio\cello\cello_D3_025_mezzo-piano_arco-normal.mp3
# get 411 of 4555 = ./audio\cello\cello_D3_025_pianissimo_arco-normal.mp3
# get 412 of 4555 = ./audio\cello\cello_D3_05_forte_arco-normal.mp3
# get 413 of 4555 = ./audio\cello\cello_D3_05_fortissimo_arco-normal.mp3
# get 414 of 4555 = ./audio\cello\cello_D3_05_mezzo-piano_arco-normal.mp3
# get 415 of 4555 = ./audio\cello\cello_D3_05_pianissimo_arco-normal.mp3
# get 416 of 4555 = ./audio\cello\cello_D3_15_forte_arco-normal.mp3
# get 417 of 4555 = ./audio\cello\cello_D3_15_fortissimo_arco-normal.mp3
# get 418 of 4555 = ./audio\cello\cello_D3_15_mezzo-piano_arco-normal.mp3
# get 419 of 4555 = ./audio\cello\cello_D3_15_pianissimo_arco-normal.mp3
# get 420 of 4555 = ./audio\cello\cello_D3_1_forte_arco-normal.mp3
# get 421 of 4555 = ./audio\cello\cello_D3_1_fortissimo_arco-normal.mp3
# get 422 of 4555 = ./audio\cello\cello_D3_1_mezzo-piano_arco-normal.mp3
# get 423 of 4555 = ./audio\cello\cello_D3_1_pianissimo_arco-normal.mp3
# get 424 of 4555 = ./audio\cello\cello_D3_phrase_fortissimo_arco-au-talon.mp3
# get 425 of 4555 = ./audio\cello\cello_D3_phrase_mezzo-forte_arco-detache.mp3
# get 426 of 4555 = ./audio\cello\cello_D3_phrase_mezzo-forte_arco-legato.mp3
# get 427 of 4555 = ./audio\cello\cello_D3_phrase_mezzo-forte_arco-spiccato.mp3
# get 428 of 4555 = ./audio\cello\cello_D3_phrase_mezzo-forte_arco-staccato.mp3
# get 429 of 4555 = ./audio\cello\cello_D4_025_forte_arco-normal.mp3
# get 430 of 4555 = ./audio\cello\cello_D4_025_fortissimo_arco-normal.mp3
# get 431 of 4555 = ./audio\cello\cello_D4_025_mezzo-piano_arco-normal.mp3
# get 432 of 4555 = ./audio\cello\cello_D4_025_pianissimo_arco-normal.mp3
# get 433 of 4555 = ./audio\cello\cello_D4_05_fortissimo_arco-normal.mp3
# get 434 of 4555 = ./audio\cello\cello_D4_05_mezzo-piano_arco-normal.mp3
# get 435 of 4555 = ./audio\cello\cello_D4_05_pianissimo_arco-normal.mp3
# get 436 of 4555 = ./audio\cello\cello_D4_15_forte_arco-normal.mp3
# get 437 of 4555 = ./audio\cello\cello_D4_15_fortissimo_arco-normal.mp3
# get 438 of 4555 = ./audio\cello\cello_D4_15_mezzo-piano_arco-normal.mp3
# get 439 of 4555 = ./audio\cello\cello_D4_15_pianissimo_arco-normal.mp3
# get 440 of 4555 = ./audio\cello\cello_D4_1_forte_arco-normal.mp3
# get 441 of 4555 = ./audio\cello\cello_D4_1_fortissimo_arco-normal.mp3
# get 442 of 4555 = ./audio\cello\cello_D4_1_mezzo-piano_arco-normal.mp3
# get 443 of 4555 = ./audio\cello\cello_D4_1_pianissimo_arco-normal.mp3
# get 444 of 4555 = ./audio\cello\cello_D4_phrase_fortissimo_arco-tremolo.mp3
# get 445 of 4555 = ./audio\cello\cello_D4_phrase_mezzo-forte_arco-detache.mp3
# get 446 of 4555 = ./audio\cello\cello_D4_phrase_mezzo-forte_arco-legato.mp3
# get 447 of 4555 = ./audio\cello\cello_D4_phrase_mezzo-forte_arco-spiccato.mp3
# get 448 of 4555 = ./audio\cello\cello_D4_phrase_mezzo-forte_arco-staccato.mp3
# get 449 of 4555 = ./audio\cello\cello_D5_025_forte_arco-normal.mp3
# get 450 of 4555 = ./audio\cello\cello_D5_025_fortissimo_arco-normal.mp3
# get 451 of 4555 = ./audio\cello\cello_D5_025_mezzo-forte_arco-col-legno-battuto.mp3
# get 452 of 4555 = ./audio\cello\cello_D5_025_mezzo-piano_arco-normal.mp3
# get 453 of 4555 = ./audio\cello\cello_D5_025_pianissimo_arco-normal.mp3
# get 454 of 4555 = ./audio\cello\cello_D5_05_forte_arco-normal.mp3
# get 455 of 4555 = ./audio\cello\cello_D5_05_fortissimo_arco-normal.mp3
# get 456 of 4555 = ./audio\cello\cello_D5_05_pianissimo_arco-normal.mp3
# get 457 of 4555 = ./audio\cello\cello_D5_15_forte_arco-normal.mp3
# get 458 of 4555 = ./audio\cello\cello_D5_15_mezzo-piano_arco-normal.mp3
# get 459 of 4555 = ./audio\cello\cello_D5_1_forte_arco-normal.mp3
# get 460 of 4555 = ./audio\cello\cello_D5_1_fortissimo_arco-normal.mp3
# get 461 of 4555 = ./audio\cello\cello_D5_1_mezzo-piano_arco-minor-trill.mp3
# get 462 of 4555 = ./audio\cello\cello_D5_1_mezzo-piano_arco-normal.mp3
# get 463 of 4555 = ./audio\cello\cello_D5_1_pianissimo_arco-normal.mp3
# get 464 of 4555 = ./audio\cello\cello_Ds2_025_forte_arco-normal.mp3
# get 465 of 4555 = ./audio\cello\cello_Ds2_025_fortissimo_arco-normal.mp3
# get 466 of 4555 = ./audio\cello\cello_Ds2_025_mezzo-forte_arco-col-legno-battuto.mp3
# get 467 of 4555 = ./audio\cello\cello_Ds2_025_mezzo-piano_arco-normal.mp3
# get 468 of 4555 = ./audio\cello\cello_Ds2_025_pianissimo_arco-normal.mp3
# get 469 of 4555 = ./audio\cello\cello_Ds2_05_forte_arco-normal.mp3
# get 470 of 4555 = ./audio\cello\cello_Ds2_05_fortissimo_arco-normal.mp3
# get 471 of 4555 = ./audio\cello\cello_Ds2_05_pianissimo_arco-normal.mp3
# get 472 of 4555 = ./audio\cello\cello_Ds2_05_piano_arco-normal.mp3
# get 473 of 4555 = ./audio\cello\cello_Ds2_15_forte_arco-normal.mp3
# get 474 of 4555 = ./audio\cello\cello_Ds2_15_fortissimo_arco-normal.mp3
# get 475 of 4555 = ./audio\cello\cello_Ds2_15_pianissimo_arco-normal.mp3
# get 476 of 4555 = ./audio\cello\cello_Ds2_15_piano_arco-normal.mp3
# get 477 of 4555 = ./audio\cello\cello_Ds2_1_forte_arco-normal.mp3
# get 478 of 4555 = ./audio\cello\cello_Ds2_1_fortissimo_arco-normal.mp3
# get 479 of 4555 = ./audio\cello\cello_Ds2_1_mezzo-piano_molto-vibrato.mp3
# get 480 of 4555 = ./audio\cello\cello_Ds2_1_mezzo-piano_non-vibrato.mp3
# get 481 of 4555 = ./audio\cello\cello_Ds2_1_pianissimo_arco-normal.mp3
# get 482 of 4555 = ./audio\cello\cello_Ds2_1_piano_arco-normal.mp3
# get 483 of 4555 = ./audio\cello\cello_Ds3_025_fortissimo_arco-normal.mp3
# get 484 of 4555 = ./audio\cello\cello_Ds3_025_mezzo-forte_arco-col-legno-battuto.mp3
# get 485 of 4555 = ./audio\cello\cello_Ds3_025_pianissimo_arco-normal.mp3
# get 486 of 4555 = ./audio\cello\cello_Ds3_025_piano_arco-normal.mp3
# get 487 of 4555 = ./audio\cello\cello_Ds3_05_fortissimo_arco-normal.mp3
# get 488 of 4555 = ./audio\cello\cello_Ds3_05_pianissimo_arco-normal.mp3
# get 489 of 4555 = ./audio\cello\cello_Ds3_05_piano_arco-normal.mp3
# get 490 of 4555 = ./audio\cello\cello_Ds3_15_forte_arco-normal.mp3
# get 491 of 4555 = ./audio\cello\cello_Ds3_15_fortissimo_arco-normal.mp3
# get 492 of 4555 = ./audio\cello\cello_Ds3_15_pianissimo_arco-normal.mp3
# get 493 of 4555 = ./audio\cello\cello_Ds3_15_piano_arco-normal.mp3
# get 494 of 4555 = ./audio\cello\cello_Ds3_1_forte_arco-normal.mp3
# get 495 of 4555 = ./audio\cello\cello_Ds3_1_fortissimo_arco-normal.mp3
# get 496 of 4555 = ./audio\cello\cello_Ds3_1_mezzo-piano_arco-major-trill.mp3
# get 497 of 4555 = ./audio\cello\cello_Ds3_1_mezzo-piano_non-vibrato.mp3
# get 498 of 4555 = ./audio\cello\cello_Ds3_1_pianissimo_arco-normal.mp3
# get 499 of 4555 = ./audio\cello\cello_Ds3_1_piano_arco-normal.mp3
# get 500 of 4555 = ./audio\cello\cello_Ds4_025_forte_arco-normal.mp3
# get 501 of 4555 = ./audio\cello\cello_Ds4_025_fortissimo_arco-normal.mp3
# get 502 of 4555 = ./audio\cello\cello_Ds4_025_mezzo-piano_arco-normal.mp3
# get 503 of 4555 = ./audio\cello\cello_Ds4_025_pianissimo_arco-normal.mp3
# get 504 of 4555 = ./audio\cello\cello_Ds4_05_forte_arco-normal.mp3
# get 505 of 4555 = ./audio\cello\cello_Ds4_05_mezzo-piano_arco-normal.mp3
# get 506 of 4555 = ./audio\cello\cello_Ds4_05_pianissimo_arco-normal.mp3
# get 507 of 4555 = ./audio\cello\cello_Ds4_15_forte_arco-normal.mp3
# get 508 of 4555 = ./audio\cello\cello_Ds4_15_fortissimo_arco-normal.mp3
# get 509 of 4555 = ./audio\cello\cello_Ds4_15_mezzo-piano_arco-normal.mp3
# get 510 of 4555 = ./audio\cello\cello_Ds4_15_pianissimo_arco-normal.mp3
# get 511 of 4555 = ./audio\cello\cello_Ds4_1_forte_arco-normal.mp3
# get 512 of 4555 = ./audio\cello\cello_Ds4_1_fortissimo_arco-normal.mp3
# get 513 of 4555 = ./audio\cello\cello_Ds4_1_mezzo-piano_arco-major-trill.mp3
# get 514 of 4555 = ./audio\cello\cello_Ds4_1_mezzo-piano_arco-normal.mp3
# get 515 of 4555 = ./audio\cello\cello_Ds4_1_mezzo-piano_non-vibrato.mp3
# get 516 of 4555 = ./audio\cello\cello_Ds4_1_pianissimo_arco-normal.mp3
# get 517 of 4555 = ./audio\cello\cello_Ds5_025_forte_arco-normal.mp3
# get 518 of 4555 = ./audio\cello\cello_Ds5_025_fortissimo_arco-normal.mp3
# get 519 of 4555 = ./audio\cello\cello_Ds5_025_mezzo-piano_arco-normal.mp3
# get 520 of 4555 = ./audio\cello\cello_Ds5_025_pianissimo_arco-normal.mp3
# get 521 of 4555 = ./audio\cello\cello_Ds5_05_forte_arco-normal.mp3
# get 522 of 4555 = ./audio\cello\cello_Ds5_05_fortissimo_arco-normal.mp3
# get 523 of 4555 = ./audio\cello\cello_Ds5_05_mezzo-piano_arco-normal.mp3
# get 524 of 4555 = ./audio\cello\cello_Ds5_05_pianissimo_arco-normal.mp3
# get 525 of 4555 = ./audio\cello\cello_Ds5_15_forte_arco-normal.mp3
# get 526 of 4555 = ./audio\cello\cello_Ds5_15_fortissimo_arco-normal.mp3
# get 527 of 4555 = ./audio\cello\cello_Ds5_15_mezzo-piano_arco-normal.mp3
# get 528 of 4555 = ./audio\cello\cello_Ds5_15_pianissimo_arco-normal.mp3
# get 529 of 4555 = ./audio\cello\cello_Ds5_1_forte_arco-normal.mp3
# get 530 of 4555 = ./audio\cello\cello_Ds5_1_fortissimo_arco-normal.mp3
# get 531 of 4555 = ./audio\cello\cello_Ds5_1_mezzo-piano_arco-normal.mp3
# get 532 of 4555 = ./audio\cello\cello_Ds5_1_pianissimo_arco-normal.mp3
# get 533 of 4555 = ./audio\cello\cello_Ds6_1_mezzo-forte_arco-harmonic.mp3
# get 534 of 4555 = ./audio\cello\cello_E2_025_forte_arco-normal.mp3
# get 535 of 4555 = ./audio\cello\cello_E2_025_fortissimo_arco-normal.mp3
# get 536 of 4555 = ./audio\cello\cello_E2_025_pianissimo_arco-normal.mp3
# get 537 of 4555 = ./audio\cello\cello_E2_025_piano_arco-normal.mp3
# get 538 of 4555 = ./audio\cello\cello_E2_05_forte_arco-normal.mp3
# get 539 of 4555 = ./audio\cello\cello_E2_05_fortissimo_arco-normal.mp3
# get 540 of 4555 = ./audio\cello\cello_E2_05_pianissimo_arco-normal.mp3
# get 541 of 4555 = ./audio\cello\cello_E2_05_piano_arco-normal.mp3
# get 542 of 4555 = ./audio\cello\cello_E2_15_forte_arco-normal.mp3
# get 543 of 4555 = ./audio\cello\cello_E2_15_fortissimo_arco-normal.mp3
# get 544 of 4555 = ./audio\cello\cello_E2_15_pianissimo_arco-normal.mp3
# get 545 of 4555 = ./audio\cello\cello_E2_15_piano_arco-normal.mp3
# get 546 of 4555 = ./audio\cello\cello_E2_1_forte_arco-normal.mp3
# get 547 of 4555 = ./audio\cello\cello_E2_1_fortissimo_arco-normal.mp3
# get 548 of 4555 = ./audio\cello\cello_E2_1_mezzo-piano_non-vibrato.mp3
# get 549 of 4555 = ./audio\cello\cello_E2_1_pianissimo_arco-normal.mp3
# get 550 of 4555 = ./audio\cello\cello_E2_1_piano_arco-normal.mp3
# get 551 of 4555 = ./audio\cello\cello_E3_025_forte_arco-normal.mp3
# get 552 of 4555 = ./audio\cello\cello_E3_025_fortissimo_arco-normal.mp3
# get 553 of 4555 = ./audio\cello\cello_E3_025_mezzo-forte_arco-col-legno-battuto.mp3
# get 554 of 4555 = ./audio\cello\cello_E3_025_pianissimo_arco-normal.mp3
# get 555 of 4555 = ./audio\cello\cello_E3_025_piano_arco-normal.mp3
# get 556 of 4555 = ./audio\cello\cello_E3_05_pianissimo_arco-normal.mp3
# get 557 of 4555 = ./audio\cello\cello_E3_15_forte_arco-normal.mp3
# get 558 of 4555 = ./audio\cello\cello_E3_15_fortissimo_arco-normal.mp3
# get 559 of 4555 = ./audio\cello\cello_E3_15_pianissimo_arco-normal.mp3
# get 560 of 4555 = ./audio\cello\cello_E3_15_piano_arco-normal.mp3
# get 561 of 4555 = ./audio\cello\cello_E3_1_forte_arco-normal.mp3
# get 562 of 4555 = ./audio\cello\cello_E3_1_fortissimo_arco-normal.mp3
# get 563 of 4555 = ./audio\cello\cello_E3_1_mezzo-piano_arco-minor-trill.mp3
# get 564 of 4555 = ./audio\cello\cello_E3_1_pianissimo_arco-normal.mp3
# get 565 of 4555 = ./audio\cello\cello_E3_phrase_cresc-decresc_arco-normal.mp3
# get 566 of 4555 = ./audio\cello\cello_E4_025_forte_arco-normal.mp3
# get 567 of 4555 = ./audio\cello\cello_E4_025_fortissimo_arco-normal.mp3
# get 568 of 4555 = ./audio\cello\cello_E4_025_mezzo-forte_arco-col-legno-battuto.mp3
# get 569 of 4555 = ./audio\cello\cello_E4_025_mezzo-piano_arco-normal.mp3
# get 570 of 4555 = ./audio\cello\cello_E4_025_pianissimo_arco-normal.mp3
# get 571 of 4555 = ./audio\cello\cello_E4_05_forte_arco-normal.mp3
# get 572 of 4555 = ./audio\cello\cello_E4_05_mezzo-piano_arco-normal.mp3
# get 573 of 4555 = ./audio\cello\cello_E4_05_pianissimo_arco-normal.mp3
# get 574 of 4555 = ./audio\cello\cello_E4_15_forte_arco-normal.mp3
# get 575 of 4555 = ./audio\cello\cello_E4_15_mezzo-piano_arco-normal.mp3
# get 576 of 4555 = ./audio\cello\cello_E4_15_pianissimo_arco-normal.mp3
# get 577 of 4555 = ./audio\cello\cello_E4_1_forte_arco-normal.mp3
# get 578 of 4555 = ./audio\cello\cello_E4_1_fortissimo_arco-normal.mp3
# get 579 of 4555 = ./audio\cello\cello_E4_1_mezzo-forte_arco-harmonic.mp3
# get 580 of 4555 = ./audio\cello\cello_E4_1_mezzo-piano_arco-normal.mp3
# get 581 of 4555 = ./audio\cello\cello_E4_1_mezzo-piano_molto-vibrato.mp3
# get 582 of 4555 = ./audio\cello\cello_E4_1_pianissimo_arco-normal.mp3
# get 583 of 4555 = ./audio\cello\cello_E4_phrase_mezzo-forte_arco-detache.mp3
# get 584 of 4555 = ./audio\cello\cello_E4_phrase_mezzo-forte_arco-legato.mp3
# get 585 of 4555 = ./audio\cello\cello_E4_phrase_mezzo-forte_arco-spiccato.mp3
# get 586 of 4555 = ./audio\cello\cello_E4_phrase_mezzo-forte_arco-staccato.mp3
# get 587 of 4555 = ./audio\cello\cello_E5_025_forte_arco-normal.mp3
# get 588 of 4555 = ./audio\cello\cello_E5_025_fortissimo_arco-normal.mp3
# get 589 of 4555 = ./audio\cello\cello_E5_025_mezzo-piano_arco-normal.mp3
# get 590 of 4555 = ./audio\cello\cello_E5_025_pianissimo_arco-normal.mp3
# get 591 of 4555 = ./audio\cello\cello_E5_05_forte_arco-normal.mp3
# get 592 of 4555 = ./audio\cello\cello_E5_05_fortissimo_arco-normal.mp3
# get 593 of 4555 = ./audio\cello\cello_E5_05_mezzo-piano_arco-normal.mp3
# get 594 of 4555 = ./audio\cello\cello_E5_05_pianissimo_arco-normal.mp3
# get 595 of 4555 = ./audio\cello\cello_E5_15_forte_arco-normal.mp3
# get 596 of 4555 = ./audio\cello\cello_E5_15_fortissimo_arco-normal.mp3
# get 597 of 4555 = ./audio\cello\cello_E5_15_mezzo-piano_arco-normal.mp3
# get 598 of 4555 = ./audio\cello\cello_E5_1_forte_arco-normal.mp3
# get 599 of 4555 = ./audio\cello\cello_E5_1_fortissimo_arco-normal.mp3
# get 600 of 4555 = ./audio\cello\cello_E5_1_mezzo-forte_arco-harmonic.mp3
# get 601 of 4555 = ./audio\cello\cello_E5_1_mezzo-piano_arco-major-trill.mp3
# get 602 of 4555 = ./audio\cello\cello_E5_1_mezzo-piano_arco-normal.mp3
# get 603 of 4555 = ./audio\cello\cello_E5_1_pianissimo_arco-normal.mp3
# get 604 of 4555 = ./audio\cello\cello_E6_1_mezzo-forte_arco-harmonic.mp3
# get 605 of 4555 = ./audio\cello\cello_F2_025_forte_arco-normal.mp3
# get 606 of 4555 = ./audio\cello\cello_F2_025_fortissimo_arco-normal.mp3
# get 607 of 4555 = ./audio\cello\cello_F2_025_pianissimo_arco-normal.mp3
# get 608 of 4555 = ./audio\cello\cello_F2_025_piano_arco-normal.mp3
# get 609 of 4555 = ./audio\cello\cello_F2_05_fortissimo_arco-normal.mp3
# get 610 of 4555 = ./audio\cello\cello_F2_05_pianissimo_arco-normal.mp3
# get 611 of 4555 = ./audio\cello\cello_F2_05_piano_arco-normal.mp3
# get 612 of 4555 = ./audio\cello\cello_F2_15_forte_arco-normal.mp3
# get 613 of 4555 = ./audio\cello\cello_F2_15_fortissimo_arco-normal.mp3
# get 614 of 4555 = ./audio\cello\cello_F2_15_pianissimo_arco-normal.mp3
# get 615 of 4555 = ./audio\cello\cello_F2_15_piano_arco-normal.mp3
# get 616 of 4555 = ./audio\cello\cello_F2_1_forte_arco-normal.mp3
# get 617 of 4555 = ./audio\cello\cello_F2_1_fortissimo_arco-normal.mp3
# get 618 of 4555 = ./audio\cello\cello_F2_1_pianissimo_arco-normal.mp3
# get 619 of 4555 = ./audio\cello\cello_F2_1_piano_arco-normal.mp3
# get 620 of 4555 = ./audio\cello\cello_F2_phrase_fortissimo_arco-au-talon.mp3
# get 621 of 4555 = ./audio\cello\cello_F2_phrase_mezzo-forte_arco-detache.mp3
# get 622 of 4555 = ./audio\cello\cello_F2_phrase_mezzo-forte_arco-legato.mp3
# get 623 of 4555 = ./audio\cello\cello_F2_phrase_mezzo-forte_arco-spiccato.mp3
# get 624 of 4555 = ./audio\cello\cello_F2_phrase_mezzo-forte_arco-staccato.mp3
# get 625 of 4555 = ./audio\cello\cello_F3_025_forte_arco-normal.mp3
# get 626 of 4555 = ./audio\cello\cello_F3_025_fortissimo_arco-normal.mp3
# get 627 of 4555 = ./audio\cello\cello_F3_025_mezzo-forte_arco-col-legno-battuto.mp3
# get 628 of 4555 = ./audio\cello\cello_F3_025_pianissimo_arco-normal.mp3
# get 629 of 4555 = ./audio\cello\cello_F3_025_piano_arco-normal.mp3
# get 630 of 4555 = ./audio\cello\cello_F3_05_forte_arco-normal.mp3
# get 631 of 4555 = ./audio\cello\cello_F3_05_fortissimo_arco-normal.mp3
# get 632 of 4555 = ./audio\cello\cello_F3_05_mezzo-piano_arco-normal.mp3
# get 633 of 4555 = ./audio\cello\cello_F3_05_pianissimo_arco-normal.mp3
# get 634 of 4555 = ./audio\cello\cello_F3_15_forte_arco-normal.mp3
# get 635 of 4555 = ./audio\cello\cello_F3_15_fortissimo_arco-normal.mp3
# get 636 of 4555 = ./audio\cello\cello_F3_15_pianissimo_arco-normal.mp3
# get 637 of 4555 = ./audio\cello\cello_F3_15_piano_arco-normal.mp3
# get 638 of 4555 = ./audio\cello\cello_F3_1_forte_arco-normal.mp3
# get 639 of 4555 = ./audio\cello\cello_F3_1_fortissimo_arco-normal.mp3
# get 640 of 4555 = ./audio\cello\cello_F3_1_mezzo-piano_arco-major-trill.mp3
# get 641 of 4555 = ./audio\cello\cello_F3_1_mezzo-piano_arco-minor-trill.mp3
# get 642 of 4555 = ./audio\cello\cello_F3_1_mezzo-piano_arco-normal.mp3
# get 643 of 4555 = ./audio\cello\cello_F3_1_pianissimo_arco-normal.mp3
# get 644 of 4555 = ./audio\cello\cello_F4_025_forte_arco-normal.mp3
# get 645 of 4555 = ./audio\cello\cello_F4_025_fortissimo_arco-normal.mp3
# get 646 of 4555 = ./audio\cello\cello_F4_025_mezzo-piano_arco-normal.mp3
# get 647 of 4555 = ./audio\cello\cello_F4_025_pianissimo_arco-normal.mp3
# get 648 of 4555 = ./audio\cello\cello_F4_05_forte_arco-normal.mp3
# get 649 of 4555 = ./audio\cello\cello_F4_05_mezzo-piano_arco-normal.mp3
# get 650 of 4555 = ./audio\cello\cello_F4_05_pianissimo_arco-normal.mp3
# get 651 of 4555 = ./audio\cello\cello_F4_15_forte_arco-normal.mp3
# get 652 of 4555 = ./audio\cello\cello_F4_15_fortissimo_arco-normal.mp3
# get 653 of 4555 = ./audio\cello\cello_F4_15_mezzo-piano_arco-normal.mp3
# get 654 of 4555 = ./audio\cello\cello_F4_15_pianissimo_arco-normal.mp3
# get 655 of 4555 = ./audio\cello\cello_F4_1_forte_arco-normal.mp3
# get 656 of 4555 = ./audio\cello\cello_F4_1_fortissimo_arco-normal.mp3
# get 657 of 4555 = ./audio\cello\cello_F4_1_mezzo-piano_arco-normal.mp3
# get 658 of 4555 = ./audio\cello\cello_F4_1_mezzo-piano_non-vibrato.mp3
# get 659 of 4555 = ./audio\cello\cello_F4_1_pianissimo_arco-normal.mp3
# get 660 of 4555 = ./audio\cello\cello_F4_long_mezzo-forte_arco-harmonic.mp3
# get 661 of 4555 = ./audio\cello\cello_F5_025_forte_arco-normal.mp3
# get 662 of 4555 = ./audio\cello\cello_F5_025_fortissimo_arco-normal.mp3
# get 663 of 4555 = ./audio\cello\cello_F5_025_mezzo-piano_arco-normal.mp3
# get 664 of 4555 = ./audio\cello\cello_F5_025_pianissimo_arco-normal.mp3
# get 665 of 4555 = ./audio\cello\cello_F5_05_forte_arco-normal.mp3
# get 666 of 4555 = ./audio\cello\cello_F5_05_fortissimo_arco-normal.mp3
# get 667 of 4555 = ./audio\cello\cello_F5_05_mezzo-piano_arco-normal.mp3
# get 668 of 4555 = ./audio\cello\cello_F5_05_pianissimo_arco-normal.mp3
# get 669 of 4555 = ./audio\cello\cello_F5_15_forte_arco-normal.mp3
# get 670 of 4555 = ./audio\cello\cello_F5_15_fortissimo_arco-normal.mp3
# get 671 of 4555 = ./audio\cello\cello_F5_15_mezzo-piano_arco-normal.mp3
# get 672 of 4555 = ./audio\cello\cello_F5_1_forte_arco-normal.mp3
# get 673 of 4555 = ./audio\cello\cello_F5_1_fortissimo_arco-normal.mp3
# get 674 of 4555 = ./audio\cello\cello_F5_1_mezzo-forte_arco-harmonic.mp3
# get 675 of 4555 = ./audio\cello\cello_F5_1_mezzo-piano_arco-normal.mp3
# get 676 of 4555 = ./audio\cello\cello_F5_1_pianissimo_arco-normal.mp3
# ...
# get 4335 of 4555 = ./audio\viola\viola_Fs3_1_forte_arco-normal.mp3
# get 4336 of 4555 = ./audio\viola\viola_Fs3_1_fortissimo_arco-normal.mp3
# get 4337 of 4555 = ./audio\viola\viola_Fs3_1_fortissimo_pizz-glissando.mp3
# get 4338 of 4555 = ./audio\viola\viola_Fs3_1_fortissimo_pizz-normal.mp3
# get 4339 of 4555 = ./audio\viola\viola_Fs3_1_fortissimo_snap-pizz.mp3
# get 4340 of 4555 = ./audio\viola\viola_Fs3_1_mezzo-forte_arco-major-trill.mp3
# get 4341 of 4555 = ./audio\viola\viola_Fs3_1_mezzo-forte_arco-minor-trill.mp3
# get 4342 of 4555 = ./audio\viola\viola_Fs3_1_mezzo-forte_molto-vibrato.mp3
# get 4343 of 4555 = ./audio\viola\viola_Fs3_1_mezzo-piano_arco-normal.mp3
# get 4344 of 4555 = ./audio\viola\viola_Fs3_1_mezzo-piano_non-vibrato.mp3
# get 4345 of 4555 = ./audio\viola\viola_Fs3_1_pianissimo_arco-normal.mp3
# get 4346 of 4555 = ./audio\viola\viola_Fs3_1_piano_arco-glissando.mp3
# get 4347 of 4555 = ./audio\viola\viola_Fs3_1_piano_arco-normal.mp3
# get 4348 of 4555 = ./audio\viola\viola_Fs3_1_piano_pizz-normal.mp3
# get 4349 of 4555 = ./audio\viola\viola_Fs4_025_forte_arco-normal.mp3
# get 4350 of 4555 = ./audio\viola\viola_Fs4_025_fortissimo_arco-normal.mp3
# get 4351 of 4555 = ./audio\viola\viola_Fs4_025_pianissimo_arco-normal.mp3
# get 4352 of 4555 = ./audio\viola\viola_Fs4_025_piano_arco-normal.mp3
# get 4353 of 4555 = ./audio\viola\viola_Fs4_05_forte_arco-normal.mp3
# get 4354 of 4555 = ./audio\viola\viola_Fs4_05_fortissimo_arco-normal.mp3
# get 4355 of 4555 = ./audio\viola\viola_Fs4_05_pianissimo_arco-normal.mp3
# get 4356 of 4555 = ./audio\viola\viola_Fs4_05_piano_arco-normal.mp3
# get 4357 of 4555 = ./audio\viola\viola_Fs4_15_fortissimo_arco-normal.mp3
# get 4358 of 4555 = ./audio\viola\viola_Fs4_15_mezzo-piano_arco-normal.mp3
# get 4359 of 4555 = ./audio\viola\viola_Fs4_15_pianissimo_arco-normal.mp3
# get 4360 of 4555 = ./audio\viola\viola_Fs4_1_fortissimo_arco-normal.mp3
# get 4361 of 4555 = ./audio\viola\viola_Fs4_1_fortissimo_pizz-glissando.mp3
# get 4362 of 4555 = ./audio\viola\viola_Fs4_1_fortissimo_snap-pizz.mp3
# get 4363 of 4555 = ./audio\viola\viola_Fs4_1_mezzo-piano_arco-normal.mp3
# get 4364 of 4555 = ./audio\viola\viola_Fs4_1_pianissimo_arco-normal.mp3
# get 4365 of 4555 = ./audio\viola\viola_Fs4_1_piano_arco-glissando.mp3
# get 4366 of 4555 = ./audio\viola\viola_Fs5_025_forte_arco-normal.mp3
# get 4367 of 4555 = ./audio\viola\viola_Fs5_025_fortissimo_arco-normal.mp3
# get 4368 of 4555 = ./audio\viola\viola_Fs5_025_pianissimo_arco-normal.mp3
# get 4369 of 4555 = ./audio\viola\viola_Fs5_025_piano_arco-normal.mp3
# get 4370 of 4555 = ./audio\viola\viola_Fs5_05_forte_arco-normal.mp3
# get 4371 of 4555 = ./audio\viola\viola_Fs5_05_fortissimo_arco-normal.mp3
# get 4372 of 4555 = ./audio\viola\viola_Fs5_05_pianissimo_arco-normal.mp3
# get 4373 of 4555 = ./audio\viola\viola_Fs5_05_piano_arco-normal.mp3
# get 4374 of 4555 = ./audio\viola\viola_Fs5_15_forte_arco-normal.mp3
# get 4375 of 4555 = ./audio\viola\viola_Fs5_15_pianissimo_arco-normal.mp3
# get 4376 of 4555 = ./audio\viola\viola_Fs5_15_piano_arco-normal.mp3
# get 4377 of 4555 = ./audio\viola\viola_Fs5_1_forte_arco-normal.mp3
# get 4378 of 4555 = ./audio\viola\viola_Fs5_1_fortissimo_arco-normal.mp3
# get 4379 of 4555 = ./audio\viola\viola_Fs5_1_mezzo-forte_arco-major-trill.mp3
# get 4380 of 4555 = ./audio\viola\viola_Fs5_1_mezzo-forte_arco-minor-trill.mp3
# get 4381 of 4555 = ./audio\viola\viola_Fs5_1_mezzo-forte_artificial-harmonic.mp3
# get 4382 of 4555 = ./audio\viola\viola_Fs5_1_mezzo-forte_molto-vibrato.mp3
# get 4383 of 4555 = ./audio\viola\viola_Fs5_1_mezzo-piano_non-vibrato.mp3
# get 4384 of 4555 = ./audio\viola\viola_Fs5_1_pianissimo_arco-normal.mp3
# get 4385 of 4555 = ./audio\viola\viola_Fs5_1_piano_arco-glissando.mp3
# get 4386 of 4555 = ./audio\viola\viola_Fs5_1_piano_arco-normal.mp3
# get 4387 of 4555 = ./audio\viola\viola_Fs5_1_piano_pizz-normal.mp3
# get 4388 of 4555 = ./audio\viola\viola_Fs5_long_mezzo-forte_artificial-harmonic.mp3
# get 4389 of 4555 = ./audio\viola\viola_Fs5_long_mezzo-forte_natural-harmonic.mp3
# get 4390 of 4555 = ./audio\viola\viola_Fs6_025_forte_arco-normal.mp3
# get 4391 of 4555 = ./audio\viola\viola_Fs6_025_fortissimo_arco-normal.mp3
# get 4392 of 4555 = ./audio\viola\viola_Fs6_025_piano_arco-normal.mp3
# get 4393 of 4555 = ./audio\viola\viola_Fs6_05_forte_arco-normal.mp3
# get 4394 of 4555 = ./audio\viola\viola_Fs6_05_fortissimo_arco-normal.mp3
# get 4395 of 4555 = ./audio\viola\viola_Fs6_05_piano_arco-normal.mp3
# get 4396 of 4555 = ./audio\viola\viola_Fs6_15_fortissimo_arco-normal.mp3
# get 4397 of 4555 = ./audio\viola\viola_Fs6_15_piano_arco-normal.mp3
# get 4398 of 4555 = ./audio\viola\viola_Fs6_1_fortissimo_arco-normal.mp3
# get 4399 of 4555 = ./audio\viola\viola_Fs6_1_mezzo-piano_arco-normal.mp3
# get 4400 of 4555 = ./audio\viola\viola_Fs6_1_pianissimo_arco-normal.mp3
# get 4401 of 4555 = ./audio\viola\viola_Fs6_1_piano_arco-normal.mp3
# get 4402 of 4555 = ./audio\viola\viola_Fs6_long_mezzo-forte_natural-harmonic.mp3
# get 4403 of 4555 = ./audio\viola\viola_Fs7_long_mezzo-forte_artificial-harmonic.mp3
# get 4404 of 4555 = ./audio\viola\viola_G3_025_forte_arco-normal.mp3
# get 4405 of 4555 = ./audio\viola\viola_G3_025_fortissimo_arco-normal.mp3
# get 4406 of 4555 = ./audio\viola\viola_G3_025_mezzo-piano_arco-normal.mp3
# get 4407 of 4555 = ./audio\viola\viola_G3_025_pianissimo_arco-normal.mp3
# get 4408 of 4555 = ./audio\viola\viola_G3_025_piano_arco-normal.mp3
# get 4409 of 4555 = ./audio\viola\viola_G3_05_forte_arco-normal.mp3
# get 4410 of 4555 = ./audio\viola\viola_G3_05_fortissimo_arco-normal.mp3
# get 4411 of 4555 = ./audio\viola\viola_G3_05_mezzo-piano_arco-normal.mp3
# get 4412 of 4555 = ./audio\viola\viola_G3_05_pianissimo_arco-normal.mp3
# get 4413 of 4555 = ./audio\viola\viola_G3_05_piano_arco-normal.mp3
# get 4414 of 4555 = ./audio\viola\viola_G3_15_pianissimo_arco-normal.mp3
# get 4415 of 4555 = ./audio\viola\viola_G3_15_piano_arco-normal.mp3
# get 4416 of 4555 = ./audio\viola\viola_G3_1_fortissimo_arco-normal.mp3
# get 4417 of 4555 = ./audio\viola\viola_G3_1_fortissimo_pizz-normal.mp3
# get 4418 of 4555 = ./audio\viola\viola_G3_1_mezzo-forte_arco-major-trill.mp3
# get 4419 of 4555 = ./audio\viola\viola_G3_1_mezzo-forte_arco-minor-trill.mp3
# get 4420 of 4555 = ./audio\viola\viola_G3_1_mezzo-forte_molto-vibrato.mp3
# get 4421 of 4555 = ./audio\viola\viola_G3_1_mezzo-piano_non-vibrato.mp3
# get 4422 of 4555 = ./audio\viola\viola_G3_1_pianissimo_arco-normal.mp3
# get 4423 of 4555 = ./audio\viola\viola_G3_1_piano_arco-normal.mp3
# get 4424 of 4555 = ./audio\viola\viola_G3_1_piano_pizz-normal.mp3
# get 4425 of 4555 = ./audio\viola\viola_G3_phrase_fortissimo_arco-tremolo.mp3
# get 4426 of 4555 = ./audio\viola\viola_G3_phrase_mezzo-forte_arco-detache.mp3
# get 4427 of 4555 = ./audio\viola\viola_G3_phrase_mezzo-forte_arco-legato.mp3
# get 4428 of 4555 = ./audio\viola\viola_G3_phrase_mezzo-forte_arco-spiccato.mp3
# get 4429 of 4555 = ./audio\viola\viola_G3_phrase_mezzo-forte_arco-staccato.mp3
# get 4430 of 4555 = ./audio\viola\viola_G4_025_forte_arco-normal.mp3
# get 4431 of 4555 = ./audio\viola\viola_G4_025_fortissimo_arco-normal.mp3
# get 4432 of 4555 = ./audio\viola\viola_G4_025_pianissimo_arco-normal.mp3
# get 4433 of 4555 = ./audio\viola\viola_G4_025_piano_arco-normal.mp3
# get 4434 of 4555 = ./audio\viola\viola_G4_05_forte_arco-normal.mp3
# get 4435 of 4555 = ./audio\viola\viola_G4_05_fortissimo_arco-normal.mp3
# get 4436 of 4555 = ./audio\viola\viola_G4_05_pianissimo_arco-normal.mp3
# get 4437 of 4555 = ./audio\viola\viola_G4_05_piano_arco-normal.mp3
# get 4438 of 4555 = ./audio\viola\viola_G4_15_forte_arco-normal.mp3
# get 4439 of 4555 = ./audio\viola\viola_G4_15_fortissimo_arco-normal.mp3
# get 4440 of 4555 = ./audio\viola\viola_G4_1_forte_arco-normal.mp3
# get 4441 of 4555 = ./audio\viola\viola_G4_1_fortissimo_arco-normal.mp3
# get 4442 of 4555 = ./audio\viola\viola_G4_1_fortissimo_pizz-normal.mp3
# get 4443 of 4555 = ./audio\viola\viola_G4_1_mezzo-forte_arco-major-trill.mp3
# get 4444 of 4555 = ./audio\viola\viola_G4_1_mezzo-forte_arco-minor-trill.mp3
# get 4445 of 4555 = ./audio\viola\viola_G4_1_mezzo-forte_molto-vibrato.mp3
# get 4446 of 4555 = ./audio\viola\viola_G4_1_mezzo-piano_non-vibrato.mp3
# get 4447 of 4555 = ./audio\viola\viola_G4_1_pianissimo_arco-normal.mp3
# get 4448 of 4555 = ./audio\viola\viola_G4_1_piano_arco-glissando.mp3
# get 4449 of 4555 = ./audio\viola\viola_G4_1_piano_arco-normal.mp3
# get 4450 of 4555 = ./audio\viola\viola_G4_1_piano_pizz-normal.mp3
# get 4451 of 4555 = ./audio\viola\viola_G4_long_mezzo-forte_natural-harmonic.mp3
# get 4452 of 4555 = ./audio\viola\viola_G4_phrase_fortissimo_arco-au-talon.mp3
# get 4453 of 4555 = ./audio\viola\viola_G4_phrase_mezzo-forte_arco-detache.mp3
# get 4454 of 4555 = ./audio\viola\viola_G4_phrase_mezzo-forte_arco-legato.mp3
# get 4455 of 4555 = ./audio\viola\viola_G4_phrase_mezzo-forte_arco-spiccato.mp3
# get 4456 of 4555 = ./audio\viola\viola_G4_phrase_mezzo-forte_arco-staccato.mp3
# get 4457 of 4555 = ./audio\viola\viola_G4_very-long_mezzo-forte_arco-normal.mp3
# get 4458 of 4555 = ./audio\viola\viola_G5_025_forte_arco-normal.mp3
# get 4459 of 4555 = ./audio\viola\viola_G5_025_fortissimo_arco-normal.mp3
# get 4460 of 4555 = ./audio\viola\viola_G5_025_pianissimo_arco-normal.mp3
# get 4461 of 4555 = ./audio\viola\viola_G5_025_piano_arco-normal.mp3
# get 4462 of 4555 = ./audio\viola\viola_G5_05_forte_arco-normal.mp3
# get 4463 of 4555 = ./audio\viola\viola_G5_05_fortissimo_arco-normal.mp3
# get 4464 of 4555 = ./audio\viola\viola_G5_05_mezzo-piano_arco-normal.mp3
# get 4465 of 4555 = ./audio\viola\viola_G5_05_pianissimo_arco-normal.mp3
# get 4466 of 4555 = ./audio\viola\viola_G5_05_piano_arco-normal.mp3
# get 4467 of 4555 = ./audio\viola\viola_G5_15_fortissimo_arco-normal.mp3
# get 4468 of 4555 = ./audio\viola\viola_G5_15_piano_arco-normal.mp3
# get 4469 of 4555 = ./audio\viola\viola_G5_1_forte_arco-normal.mp3
# get 4470 of 4555 = ./audio\viola\viola_G5_1_fortissimo_arco-normal.mp3
# get 4471 of 4555 = ./audio\viola\viola_G5_1_mezzo-forte_artificial-harmonic.mp3
# get 4472 of 4555 = ./audio\viola\viola_G5_1_pianissimo_arco-normal.mp3
# get 4473 of 4555 = ./audio\viola\viola_G5_1_piano_arco-normal.mp3
# get 4474 of 4555 = ./audio\viola\viola_G5_long_mezzo-forte_artificial-harmonic.mp3
# get 4475 of 4555 = ./audio\viola\viola_G5_long_mezzo-forte_natural-harmonic.mp3
# get 4476 of 4555 = ./audio\viola\viola_G6_025_forte_arco-normal.mp3
# get 4477 of 4555 = ./audio\viola\viola_G6_025_fortissimo_arco-normal.mp3
# get 4478 of 4555 = ./audio\viola\viola_G6_025_pianissimo_arco-normal.mp3
# get 4479 of 4555 = ./audio\viola\viola_G6_025_piano_arco-normal.mp3
# get 4480 of 4555 = ./audio\viola\viola_G6_05_forte_arco-normal.mp3
# get 4481 of 4555 = ./audio\viola\viola_G6_05_fortissimo_arco-normal.mp3
# get 4482 of 4555 = ./audio\viola\viola_G6_05_pianissimo_arco-normal.mp3
# get 4483 of 4555 = ./audio\viola\viola_G6_05_piano_arco-normal.mp3
# get 4484 of 4555 = ./audio\viola\viola_G6_15_fortissimo_arco-normal.mp3
# get 4485 of 4555 = ./audio\viola\viola_G6_15_pianissimo_arco-normal.mp3
# get 4486 of 4555 = ./audio\viola\viola_G6_1_forte_arco-normal.mp3
# get 4487 of 4555 = ./audio\viola\viola_G6_1_fortissimo_arco-normal.mp3
# get 4488 of 4555 = ./audio\viola\viola_G6_1_pianissimo_arco-normal.mp3
# get 4489 of 4555 = ./audio\viola\viola_G6_1_piano_arco-normal.mp3
# get 4490 of 4555 = ./audio\viola\viola_Gs3_025_fortissimo_arco-normal.mp3
# get 4491 of 4555 = ./audio\viola\viola_Gs3_025_mezzo-piano_arco-normal.mp3
# get 4492 of 4555 = ./audio\viola\viola_Gs3_025_pianissimo_arco-normal.mp3
# get 4493 of 4555 = ./audio\viola\viola_Gs3_025_piano_arco-normal.mp3
# get 4494 of 4555 = ./audio\viola\viola_Gs3_05_fortissimo_arco-normal.mp3
# get 4495 of 4555 = ./audio\viola\viola_Gs3_05_mezzo-piano_arco-normal.mp3
# get 4496 of 4555 = ./audio\viola\viola_Gs3_05_pianissimo_arco-normal.mp3
# get 4497 of 4555 = ./audio\viola\viola_Gs3_05_piano_arco-normal.mp3
# get 4498 of 4555 = ./audio\viola\viola_Gs3_15_fortissimo_arco-normal.mp3
# get 4499 of 4555 = ./audio\viola\viola_Gs3_15_pianissimo_arco-normal.mp3
# get 4500 of 4555 = ./audio\viola\viola_Gs3_15_piano_arco-normal.mp3
# get 4501 of 4555 = ./audio\viola\viola_Gs3_1_forte_arco-normal.mp3
# get 4502 of 4555 = ./audio\viola\viola_Gs3_1_fortissimo_arco-normal.mp3
# get 4503 of 4555 = ./audio\viola\viola_Gs3_1_fortissimo_pizz-normal.mp3
# get 4504 of 4555 = ./audio\viola\viola_Gs3_1_mezzo-forte_arco-major-trill.mp3
# get 4505 of 4555 = ./audio\viola\viola_Gs3_1_mezzo-forte_arco-minor-trill.mp3
# get 4506 of 4555 = ./audio\viola\viola_Gs3_1_mezzo-forte_molto-vibrato.mp3
# get 4507 of 4555 = ./audio\viola\viola_Gs3_1_mezzo-piano_arco-normal.mp3
# get 4508 of 4555 = ./audio\viola\viola_Gs3_1_mezzo-piano_non-vibrato.mp3
# get 4509 of 4555 = ./audio\viola\viola_Gs3_1_pianissimo_arco-normal.mp3
# get 4510 of 4555 = ./audio\viola\viola_Gs3_1_piano_arco-glissando.mp3
# get 4511 of 4555 = ./audio\viola\viola_Gs3_1_piano_arco-normal.mp3
# get 4512 of 4555 = ./audio\viola\viola_Gs3_1_piano_pizz-normal.mp3
# get 4513 of 4555 = ./audio\viola\viola_Gs4_025_fortissimo_arco-normal.mp3
# get 4514 of 4555 = ./audio\viola\viola_Gs4_025_mezzo-piano_arco-normal.mp3
# get 4515 of 4555 = ./audio\viola\viola_Gs4_025_pianissimo_arco-normal.mp3
# get 4516 of 4555 = ./audio\viola\viola_Gs4_05_fortissimo_arco-normal.mp3
# get 4517 of 4555 = ./audio\viola\viola_Gs4_05_mezzo-piano_arco-normal.mp3
# get 4518 of 4555 = ./audio\viola\viola_Gs4_05_pianissimo_arco-normal.mp3
# get 4519 of 4555 = ./audio\viola\viola_Gs4_05_piano_arco-normal.mp3
# get 4520 of 4555 = ./audio\viola\viola_Gs4_15_fortissimo_arco-normal.mp3
# get 4521 of 4555 = ./audio\viola\viola_Gs4_15_mezzo-piano_arco-normal.mp3
# get 4522 of 4555 = ./audio\viola\viola_Gs4_15_pianissimo_arco-normal.mp3
# get 4523 of 4555 = ./audio\viola\viola_Gs4_1_fortissimo_arco-normal.mp3
# get 4524 of 4555 = ./audio\viola\viola_Gs4_1_mezzo-piano_arco-normal.mp3
# get 4525 of 4555 = ./audio\viola\viola_Gs4_1_pianissimo_arco-normal.mp3
# get 4526 of 4555 = ./audio\viola\viola_Gs4_1_piano_arco-normal.mp3
# get 4527 of 4555 = ./audio\viola\viola_Gs5_025_forte_arco-normal.mp3
# get 4528 of 4555 = ./audio\viola\viola_Gs5_025_fortissimo_arco-normal.mp3
# get 4529 of 4555 = ./audio\viola\viola_Gs5_025_mezzo-piano_arco-normal.mp3
# get 4530 of 4555 = ./audio\viola\viola_Gs5_025_pianissimo_arco-normal.mp3
# get 4531 of 4555 = ./audio\viola\viola_Gs5_05_forte_arco-normal.mp3
# get 4532 of 4555 = ./audio\viola\viola_Gs5_05_fortissimo_arco-normal.mp3
# get 4533 of 4555 = ./audio\viola\viola_Gs5_05_pianissimo_arco-normal.mp3
# get 4534 of 4555 = ./audio\viola\viola_Gs5_05_piano_arco-normal.mp3
# get 4535 of 4555 = ./audio\viola\viola_Gs5_15_fortissimo_arco-normal.mp3
# get 4536 of 4555 = ./audio\viola\viola_Gs5_15_pianissimo_arco-normal.mp3
# get 4537 of 4555 = ./audio\viola\viola_Gs5_1_forte_arco-normal.mp3
# get 4538 of 4555 = ./audio\viola\viola_Gs5_1_fortissimo_arco-normal.mp3
# get 4539 of 4555 = ./audio\viola\viola_Gs5_1_fortissimo_snap-pizz.mp3
# get 4540 of 4555 = ./audio\viola\viola_Gs5_1_pianissimo_arco-normal.mp3
# get 4541 of 4555 = ./audio\viola\viola_Gs5_1_piano_arco-normal.mp3
# get 4542 of 4555 = ./audio\viola\viola_Gs6_025_forte_arco-normal.mp3
# get 4543 of 4555 = ./audio\viola\viola_Gs6_025_fortissimo_arco-normal.mp3
# get 4544 of 4555 = ./audio\viola\viola_Gs6_025_mezzo-piano_arco-normal.mp3
# get 4545 of 4555 = ./audio\viola\viola_Gs6_025_pianissimo_arco-normal.mp3
# get 4546 of 4555 = ./audio\viola\viola_Gs6_025_piano_arco-normal.mp3
# get 4547 of 4555 = ./audio\viola\viola_Gs6_05_forte_arco-normal.mp3
# get 4548 of 4555 = ./audio\viola\viola_Gs6_05_fortissimo_arco-normal.mp3
# get 4549 of 4555 = ./audio\viola\viola_Gs6_05_pianissimo_arco-normal.mp3
# get 4550 of 4555 = ./audio\viola\viola_Gs6_05_piano_arco-normal.mp3
# get 4551 of 4555 = ./audio\viola\viola_Gs6_15_forte_arco-normal.mp3
# get 4552 of 4555 = ./audio\viola\viola_Gs6_15_fortissimo_arco-normal.mp3
# get 4553 of 4555 = ./audio\viola\viola_Gs6_1_forte_arco-normal.mp3
# get 4554 of 4555 = ./audio\viola\viola_Gs6_1_fortissimo_arco-normal.mp3
# get 4555 of 4555 = ./audio\viola\viola_Gs6_1_pianissimo_arco-normal.mp3
# Calculated 4553 feature vectors

# %%
#NORMALIZATION OF DATASET 

scaler = StandardScaler()
scaled_feature_vectors = scaler.fit_transform(np.array(feature_vectors))
print("Feature vectors shape:", scaled_feature_vectors.shape)
# Out:
# Feature vectors shape: (4553, 13)

# %%
#LOADING MFCC FEATURE 

filename = "mfcc_feature_vectors.p1"
#scaled_feature_vectors = pickle.load( open(filename, "rb"))

# Save feature_vectors for future use 
with open(filename, "wb") as f:
    pickle.dump( scaled_feature_vectors, f)

# %%
scaled_feature_vectors.shape[0]
# Out:
# 4553

# %%
classes_num = np.delete(classes_num, 0)
classes_num.shape[0]
# Out:
# 4553

# %%
# Machine learning parameters
testset_size = 0.25
n_neighbours = 1

# %%
splitter = StratifiedShuffleSplit(n_splits=1, test_size=testset_size, random_state=0)
splits = splitter.split(scaled_feature_vectors, classes_num)
    #print(train_index, test_index)
    #print(splits)
    
for train_index, test_index in splits: 
    train_set = scaled_feature_vectors[train_index] 
    test_set = scaled_feature_vectors[test_index] 
    train_classes = classes_num[train_index] 
    test_classes = classes_num[test_index]

# %%
print("train_set shape: ", train_set.shape)
print("test_set shape: ", test_set.shape)
print("train_classes shape: ", train_classes.shape)
print("test_classes shape: ", test_classes.shape)
# Out:
# train_set shape:  (3414, 13)
# test_set shape:  (1139, 13)
# train_classes shape:  (3414,)
# test_classes shape:  (1139,)

# %%
# with n = 1

n_neighbors = 1
model_knn = KNeighborsClassifier(n_neighbors = n_neighbors)
#KNN 
model_knn.fit(train_set, train_classes);
#Predict using the test set 
predicted_labels = model_knn.predict(test_set)

#model_knn.kneighbors_graph(train_set, n_neighbors, mode='connectivity')

# %%
#12) EVALUATION

#Recall the ability of the classifier to find all the positive samples 
print("Recall: ", recall_score(test_classes, predicted_labels, average= None))

#Precision - The precision is intuitively the ability of the classifier not to label as positive a sample that is negative 
print("Precision: ", precision_score(test_classes, predicted_labels, average=None))

#F1-Score- The F1 score can be interpreted as a weighted average of the precision and recall
print("F1-Score: ",f1_score(test_classes,predicted_labels,average=None))

#Accuracy - the number of correctly classified samples 
print("Accuracy: %.2f ,"%accuracy_score(test_classes, predicted_labels,normalize = True), accuracy_score(test_classes, predicted_labels, normalize = False))
print("Number of samples: ", test_classes.shape[0])
# Out:
# Recall:  [0.91 0.98 0.94 0.95 0.76 0.94]
# Precision:  [0.95 0.95 0.98 0.87 0.88 0.91]
# F1-Score:  [0.93 0.96 0.96 0.91 0.81 0.93]
# Accuracy: 0.92 , 1053
# Number of samples:  1139

# %%
#13)VISUALIZATION USING CONFUSION MATRIZ 

#Compute confusion matraix
cnf_matrix = confusion_matrix(test_classes, predicted_labels)
np.set_printoptions(precision=2)

#DEFINING FUNCTION FOR VISUALISING 
def plot_confusion_matrix(cm, classes, normalize =False, title='Confusion matrix',cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting 'normalize = True'.

    if normalize:
    cm = cm.astype('float')/cm.sum(axis=1)[:,np.newaxis]
    print("Normalize confusion matrix")
    else:
    print('Confusion matrix, without normalizaton')
    print(cm)
    """
    plt.imshow(cm, interpolation = 'nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 45)
    plt.yticks(tick_marks,classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() /2.
    for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j,i,format(cm[i,j], fmt), horizontalalignment="center",color="white" if cm[i,j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#PLOTING CONFUSION MATRIX 

plt.figure(figsize = (10,8))
plot_confusion_matrix(cnf_matrix, classes = labelencoder.classes_, title="Confusion matrix, without normalization")

# %%
# with n = 5

model_knn = KNeighborsClassifier(n_neighbors = 3)
#KNN 
model_knn.fit(train_set, train_classes);
#Predict using the test set 
predicted_labels = model_knn.predict(test_set)

#Recall the ability of the classifier to find all the positive samples 
print("Recall: ", recall_score(test_classes, predicted_labels, average= None))

#Precision - The precision is intuitively the ability of the classifier not to label as positive a sample that is negative 
print("Precision: ", precision_score(test_classes, predicted_labels, average=None))

#F1-Score- The F1 score can be interpreted as a weighted average of the precision and recall
print("F1-Score: ",f1_score(test_classes,predicted_labels,average=None))

#Accuracy - the number of correctly classified samples 
print("Accuracy: %.2f ,"%accuracy_score(test_classes, predicted_labels,normalize = True), accuracy_score(test_classes, predicted_labels, normalize = False))
print("Number of samples: ", test_classes.shape[0])

def plot_confusion_matrix(cm, classes, normalize =False, title='Confusion matrix',cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting 'normalize = True'.

    if normalize:
    cm = cm.astype('float')/cm.sum(axis=1)[:,np.newaxis]
    print("Normalize confusion matrix")
    else:
    print('Confusion matrix, without normalizaton')
    print(cm)
    """
    plt.imshow(cm, interpolation = 'nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 45)
    plt.yticks(tick_marks,classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() /2.
    for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j,i,format(cm[i,j], fmt), horizontalalignment="center",color="white" if cm[i,j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
 
plt.figure(figsize = (10,8))
plot_confusion_matrix(cnf_matrix, classes = labelencoder.classes_, title="Confusion matrix, with n = 3")
# Out:
# Recall:  [0.92 0.9  0.89 0.9  0.49 0.91]
# Precision:  [0.86 0.9  0.87 0.82 0.87 0.85]
# F1-Score:  [0.89 0.9  0.88 0.86 0.62 0.88]
# Accuracy: 0.86 , 981
# Number of samples:  1139

# %%
# with n = 10

n_neighbors = 10
model_knn = KNeighborsClassifier(n_neighbors = n_neighbors)
#KNN 
model_knn.fit(train_set, train_classes);
#Predict using the test set 
predicted_labels = model_knn.predict(test_set)

#Recall the ability of the classifier to find all the positive samples 
print("Recall: ", recall_score(test_classes, predicted_labels, average= None))

#Precision - The precision is intuitively the ability of the classifier not to label as positive a sample that is negative 
print("Precision: ", precision_score(test_classes, predicted_labels, average=None))

#F1-Score- The F1 score can be interpreted as a weighted average of the precision and recall
print("F1-Score: ",f1_score(test_classes,predicted_labels,average=None))

#Accuracy - the number of correctly classified samples 
print("Accuracy: %.2f ,"%accuracy_score(test_classes, predicted_labels,normalize = True), accuracy_score(test_classes, predicted_labels, normalize = False))
print("Number of samples: ", test_classes.shape[0])

   
plt.figure(figsize = (10,8))
plot_confusion_matrix(cnf_matrix, classes = labelencoder.classes_, title="Confusion matrix, without normalization")
# Out:
# Recall:  [0.94 0.92 0.94 0.92 0.52 0.91]
# Precision:  [0.89 0.92 0.88 0.81 0.9  0.9 ]
# F1-Score:  [0.92 0.92 0.91 0.86 0.66 0.9 ]
# Accuracy: 0.88 , 1006
# Number of samples:  1139

# %%
def plot_dec_boundaries(X, y, model_class, **model_params):
    reduced_data = X[:, :2]
    model = model_class(**model_params)
    model.fit(reduced_data, y)
    
    h = 0.02
    
    xmin, xmax = reduced_data[:, 0].min() - 1, reduced_data[:, 0].max() + 1
    ymin, ymax = reduced_data[:, 0].min() - 1, reduced_data[:, 0].max() + 1
    
    xx, yy = np.meshgrid(np.arange(xmin, xmax, h), np.arange(ymin, ymax, h))
    
    z = model.predict(np.c_[xx.ravel(), yy.ravel()])

# %%
# %matplotlib inline
plt.figure(figsize=((10,8)))
plot_dec_boundaries(train_set, train_classes, KNeighborsClassifier)
plt.show()
